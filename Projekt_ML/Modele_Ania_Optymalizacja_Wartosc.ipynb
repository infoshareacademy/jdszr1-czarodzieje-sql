# %% [markdown]
# ## JAKUB

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
import os
import sys
import seaborn as sn
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
# wczytanie pliku bazowego do analizy
df = pd.read_csv("workspace_table1.csv")
# print(type(df))
df.head()
# Out:
#    Unnamed: 0       ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0           0  5008804               0      C           M            Y
# 1           1  5008804              -1      C           M            Y
# 2           2  5008804              -2      C           M            Y
# 3           3  5008804              -3      C           M            Y
# 4           4  5008804              -4      C           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  ...  \
# 0               Y             0          427500.0          Working  ...
# 1               Y             0          427500.0          Working  ...
# 2               Y             0          427500.0          Working  ...
# 3               Y             0          427500.0          Working  ...
# 4               Y             0          427500.0          Working  ...
#
#   NAME_FAMILY_STATUS NAME_HOUSING_TYPE DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0     Civil marriage  Rented apartment     -12005          -4542           1
# 1     Civil marriage  Rented apartment     -12005          -4542           1
# 2     Civil marriage  Rented apartment     -12005          -4542           1
# 3     Civil marriage  Rented apartment     -12005          -4542           1
# 4     Civil marriage  Rented apartment     -12005          -4542           1
#
#    FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE CNT_FAM_MEMBERS
# 0                1           0           0              NaN             2.0
# 1                1           0           0              NaN             2.0
# 2                1           0           0              NaN             2.0
# 3                1           0           0              NaN             2.0
# 4                1           0           0              NaN             2.0
#
# [5 rows x 21 columns]

# %%
#analiza wystąpień danego STATUSU w całej bazie danych, liczba wierszy per konkretny status

df["STATUS"].value_counts()
# Out:
# C    274364
# 0    243034
# X    122423
# 1      7619
# 5      1261
# 2       652
# 3       213
# 4       177
# Name: STATUS, dtype: int64

# %%
## Usunięcie kolumny "Unnamed"
df = df.drop("Unnamed: 0", axis=1)
df
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0       5008804               0      C           M            Y
# 1       5008804              -1      C           M            Y
# 2       5008804              -2      C           M            Y
# 3       5008804              -3      C           M            Y
# 4       5008804              -4      C           M            Y
# ...         ...             ...    ...         ...          ...
# 649738  5150487             -25      C           M            Y
# 649739  5150487             -26      C           M            Y
# 649740  5150487             -27      C           M            Y
# 649741  5150487             -28      C           M            Y
# 649742  5150487             -29      C           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                    Y             0          427500.0          Working
# 1                    Y             0          427500.0          Working
# 2                    Y             0          427500.0          Working
# 3                    Y             0          427500.0          Working
# 4                    Y             0          427500.0          Working
# ...                ...           ...               ...              ...
# 649738               N             0          202500.0          Working
# 649739               N             0          202500.0          Working
# 649740               N             0          202500.0          Working
# 649741               N             0          202500.0          Working
# 649742               N             0          202500.0          Working
#
#                   NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0                    Higher education     Civil marriage   Rented apartment
# 1                    Higher education     Civil marriage   Rented apartment
# 2                    Higher education     Civil marriage   Rented apartment
# 3                    Higher education     Civil marriage   Rented apartment
# 4                    Higher education     Civil marriage   Rented apartment
# ...                               ...                ...                ...
# 649738  Secondary / secondary special            Married  House / apartment
# 649739  Secondary / secondary special            Married  House / apartment
# 649740  Secondary / secondary special            Married  House / apartment
# 649741  Secondary / secondary special            Married  House / apartment
# 649742  Secondary / secondary special            Married  House / apartment
#
#         DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0           -12005          -4542           1                1           0
# 1           -12005          -4542           1                1           0
# 2           -12005          -4542           1                1           0
# 3           -12005          -4542           1                1           0
# 4           -12005          -4542           1                1           0
# ...            ...            ...         ...              ...         ...
# 649738      -19398          -2166           1                0           0
# 649739      -19398          -2166           1                0           0
# 649740      -19398          -2166           1                0           0
# 649741      -19398          -2166           1                0           0
# 649742      -19398          -2166           1                0           0
#
#         FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0                0             NaN              2.0
# 1                0             NaN              2.0
# 2                0             NaN              2.0
# 3                0             NaN              2.0
# 4                0             NaN              2.0
# ...            ...             ...              ...
# 649738           0         Drivers              2.0
# 649739           0         Drivers              2.0
# 649740           0         Drivers              2.0
# 649741           0         Drivers              2.0
# 649742           0         Drivers              2.0
#
# [649743 rows x 20 columns]

# %%
# usnunięcie wierszy, które są X, stowrzenie nowej bazy, gdzie STATUS nie równa się == X
df1 = df[df.STATUS !="X"]

# %%
pd.set_option('float_format','{:.2f}'.format)

# %%
# sprawdzenie kolumn (w tym wypadku "AMT_INCOME_TOTAL") ogólnych miar - sprawdzenie outlierów, wartości odstających.

df1["AMT_INCOME_TOTAL"].describe()
# Out:
# count    527320.00
# mean     195631.81
# std      103859.72
# min       27000.00
# 25%      135000.00
# 50%      180000.00
# 75%      225000.00
# max     1575000.00
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
# wyrównanie wyświetlania kolumn i nagłówków

pd.options.display.max_rows = 999

# %%
# sprawdzenie ilości wystąpień ilości wierszy w określonymi miesiącami 

df["MONTHS_BALANCE"].value_counts()
# Out:
# -1     20806
# -2     20738
# -3     20557
#  0     20539
# -4     20267
# -5     19969
# -6     19631
# -7     19256
# -8     18826
# -9     18510
# -10    18211
# -11    17894
# -12    17549
# -13    17178
# -14    16788
# -15    16386
# -16    16024
# -17    15628
# -18    15167
# -19    14807
# -20    14454
# -21    14076
# -22    13741
# -23    13355
# -24    12960
# -25    12509
# -26    12080
# -27    11700
# -28    11292
# -29    10908
# -30    10508
# -31    10146
# -32     9769
# -33     9398
# -34     9044
# -35     8677
# -36     8304
# -37     7967
# -38     7624
# -39     7209
# -40     6731
# -41     6319
# -42     5937
# -43     5576
# -44     5224
# -45     4912
# -46     4586
# -47     4245
# -48     3890
# -49     3547
# -50     3223
# -51     2902
# -52     2542
# -53     2177
# -54     1890
# -55     1616
# -56     1331
# -57     1049
# -58      808
# -59      524
# -60      262
# Name: MONTHS_BALANCE, dtype: int64

# %%
# utowrzenie dla STATUSU dwóch grup 0 i 1, wykorzystując funkcję IS IN.
df1.loc[df['STATUS'].isin(['C','0','1']),'STATUS'] = '0'
# Out:
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
# testowanie i sprawdzenie, wykorzystanie counta
df1["STATUS"].value_counts()
# Out:
# 0    525017
# 5      1261
# 2       652
# 3       213
# 4       177
# Name: STATUS, dtype: int64

# %%
# utowrzenie dla STATUS dwóch grup 0 i 1, wykorzystując funkcję IS IN
df1.loc[df['STATUS'].isin(['5','3','4','2']),'STATUS'] = '1'

# %%
#testowanie i sprawdzenie, wykorzystanie counta
df1["STATUS"].value_counts()
# Out:
# 0    525017
# 1      2303
# Name: STATUS, dtype: int64

# %%
# zmiana typu kolumny STATUS
df1["STATUS"] = df1["STATUS"].astype(int)
# Out:
# <ipython-input-14-adf6a85b6bd3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["STATUS"] = df1["STATUS"].astype(int)

# %%
# usunięcie kolumny MONTH_BALANCE. Nie będzie ona nam dalej potrzebna, gdyż kolumna STATUS mówi nam czy 
#dany klient jest ok (STATUS==0) czy nie (STATUS==1)

df1 = df1.drop("MONTHS_BALANCE", axis=1)
df1
# Out:
#              ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0       5008804       0           M            Y               Y
# 1       5008804       0           M            Y               Y
# 2       5008804       0           M            Y               Y
# 3       5008804       0           M            Y               Y
# 4       5008804       0           M            Y               Y
# ...         ...     ...         ...          ...             ...
# 649738  5150487       0           M            Y               N
# 649739  5150487       0           M            Y               N
# 649740  5150487       0           M            Y               N
# 649741  5150487       0           M            Y               N
# 649742  5150487       0           M            Y               N
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0         427500.00          Working
# 1                  0         427500.00          Working
# 2                  0         427500.00          Working
# 3                  0         427500.00          Working
# 4                  0         427500.00          Working
# ...              ...               ...              ...
# 649738             0         202500.00          Working
# 649739             0         202500.00          Working
# 649740             0         202500.00          Working
# 649741             0         202500.00          Working
# 649742             0         202500.00          Working
#
#                   NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0                    Higher education     Civil marriage   Rented apartment
# 1                    Higher education     Civil marriage   Rented apartment
# 2                    Higher education     Civil marriage   Rented apartment
# 3                    Higher education     Civil marriage   Rented apartment
# 4                    Higher education     Civil marriage   Rented apartment
# ...                               ...                ...                ...
# 649738  Secondary / secondary special            Married  House / apartment
# 649739  Secondary / secondary special            Married  House / apartment
# 649740  Secondary / secondary special            Married  House / apartment
# 649741  Secondary / secondary special            Married  House / apartment
# 649742  Secondary / secondary special            Married  House / apartment
#
#         DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0           -12005          -4542           1                1           0
# 1           -12005          -4542           1                1           0
# 2           -12005          -4542           1                1           0
# 3           -12005          -4542           1                1           0
# 4           -12005          -4542           1                1           0
# ...            ...            ...         ...              ...         ...
# 649738      -19398          -2166           1                0           0
# 649739      -19398          -2166           1                0           0
# 649740      -19398          -2166           1                0           0
# 649741      -19398          -2166           1                0           0
# 649742      -19398          -2166           1                0           0
#
#         FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0                0             NaN             2.00
# 1                0             NaN             2.00
# 2                0             NaN             2.00
# 3                0             NaN             2.00
# 4                0             NaN             2.00
# ...            ...             ...              ...
# 649738           0         Drivers             2.00
# 649739           0         Drivers             2.00
# 649740           0         Drivers             2.00
# 649741           0         Drivers             2.00
# 649742           0         Drivers             2.00
#
# [527320 rows x 19 columns]

# %%
# wyliczenie STATUS dla danego klienta a następnie usunięcie duplikatów. Wszystko po to aby uzyskać unikatową wartość (czy jest ok czy nie)
# dla danego klienta

#%%time
i = 0
all_ids = len(df1["ID"].unique())
for ID in df1["ID"].unique():
    i += 1
    progress = i / all_ids
    if df1.loc[df1["ID"]== ID, "STATUS"].sum() > 0:
        df1.loc[df1["ID"]==ID, "STATUS"] = 1
    else:
        df1.loc[df1["ID"]==ID, "STATUS"] = 0
        
    if round(progress, 0) % 5 == 0:
        print(f'przeliczono {progress*100}% przypadkow')
df1.drop_duplicates(inplace=True)
df1.info()
# Out:
# przeliczono 0.0036405999708752% przypadkow
# przeliczono 0.0072811999417504% przypadkow
# przeliczono 0.010921799912625601% przypadkow
# przeliczono 0.0145623998835008% przypadkow
# przeliczono 0.018202999854376% przypadkow
# przeliczono 0.021843599825251202% przypadkow
# przeliczono 0.025484199796126403% przypadkow
# przeliczono 0.0291247997670016% przypadkow
# przeliczono 0.0327653997378768% przypadkow
# przeliczono 0.036405999708752% przypadkow
# przeliczono 0.040046599679627204% przypadkow
# przeliczono 0.043687199650502405% przypadkow
# przeliczono 0.047327799621377606% przypadkow
# przeliczono 0.05096839959225281% przypadkow
# przeliczono 0.054608999563128% przypadkow
# przeliczono 0.0582495995340032% przypadkow
# przeliczono 0.06189019950487841% przypadkow
# przeliczono 0.0655307994757536% przypadkow
# przeliczono 0.0691713994466288% przypadkow
# przeliczono 0.072811999417504% przypadkow
# przeliczono 0.0764525993883792% przypadkow
# przeliczono 0.08009319935925441% przypadkow
# przeliczono 0.08373379933012962% przypadkow
# przeliczono 0.08737439930100481% przypadkow
# przeliczono 0.09101499927188% przypadkow
# przeliczono 0.09465559924275521% przypadkow
# przeliczono 0.09829619921363039% przypadkow
# przeliczono 0.10193679918450561% przypadkow
# przeliczono 0.10557739915538081% przypadkow
# przeliczono 0.109217999126256% przypadkow
# przeliczono 0.11285859909713121% przypadkow
# przeliczono 0.1164991990680064% przypadkow
# przeliczono 0.1201397990388816% przypadkow
# przeliczono 0.12378039900975682% przypadkow
# przeliczono 0.127420998980632% przypadkow
# przeliczono 0.1310615989515072% przypadkow
# przeliczono 0.13470219892238242% przypadkow
# przeliczono 0.1383427988932576% przypadkow
# przeliczono 0.1419833988641328% przypadkow
# przeliczono 0.145623998835008% przypadkow
# przeliczono 0.14926459880588322% przypadkow
# przeliczono 0.1529051987767584% przypadkow
# przeliczono 0.1565457987476336% przypadkow
# przeliczono 0.16018639871850882% przypadkow
# przeliczono 0.163826998689384% przypadkow
# przeliczono 0.16746759866025923% przypadkow
# przeliczono 0.1711081986311344% przypadkow
# przeliczono 0.17474879860200962% przypadkow
# przeliczono 0.1783893985728848% przypadkow
# przeliczono 0.18202999854376% przypadkow
# przeliczono 0.18567059851463522% przypadkow
# przeliczono 0.18931119848551042% przypadkow
# przeliczono 0.1929517984563856% przypadkow
# przeliczono 0.19659239842726078% przypadkow
# przeliczono 0.20023299839813602% przypadkow
# przeliczono 0.20387359836901123% przypadkow
# przeliczono 0.2075141983398864% przypadkow
# przeliczono 0.21115479831076162% przypadkow
# przeliczono 0.2147953982816368% przypadkow
# przeliczono 0.218435998252512% przypadkow
# przeliczono 0.22207659822338724% przypadkow
# przeliczono 0.22571719819426242% przypadkow
# przeliczono 0.22935779816513763% przypadkow
# przeliczono 0.2329983981360128% przypadkow
# przeliczono 0.23663899810688802% przypadkow
# przeliczono 0.2402795980777632% przypadkow
# przeliczono 0.2439201980486384% przypadkow
# przeliczono 0.24756079801951364% przypadkow
# przeliczono 0.2512013979903888% przypadkow
# przeliczono 0.254841997961264% przypadkow
# przeliczono 0.2584825979321392% przypadkow
# przeliczono 0.2621231979030144% przypadkow
# przeliczono 0.26576379787388965% przypadkow
# przeliczono 0.26940439784476483% przypadkow
# przeliczono 0.27304499781564% przypadkow
# przeliczono 0.2766855977865152% przypadkow
# przeliczono 0.2803261977573904% przypadkow
# przeliczono 0.2839667977282656% przypadkow
# przeliczono 0.28760739769914084% przypadkow
# przeliczono 0.291247997670016% przypadkow
# przeliczono 0.2948885976408912% przypadkow
# przeliczono 0.29852919761176644% przypadkow
# przeliczono 0.3021697975826416% przypadkow
# przeliczono 0.3058103975535168% przypadkow
# przeliczono 0.30945099752439204% przypadkow
# przeliczono 0.3130915974952672% przypadkow
# przeliczono 0.31673219746614245% przypadkow
# przeliczono 0.32037279743701763% przypadkow
# przeliczono 0.3240133974078928% przypadkow
# przeliczono 0.327653997378768% przypadkow
# przeliczono 0.3312945973496432% przypadkow
# przeliczono 0.33493519732051846% przypadkow
# przeliczono 0.3385757972913936% przypadkow
# przeliczono 0.3422163972622688% przypadkow
# przeliczono 0.345856997233144% przypadkow
# przeliczono 0.34949759720401924% przypadkow
# przeliczono 0.3531381971748944% przypadkow
# przeliczono 0.3567787971457696% przypadkow
# przeliczono 0.36041939711664484% przypadkow
# przeliczono 0.36405999708752% przypadkow
# przeliczono 0.36770059705839525% przypadkow
# przeliczono 0.37134119702927043% przypadkow
# przeliczono 0.3749817970001456% przypadkow
# przeliczono 0.37862239697102085% przypadkow
# przeliczono 0.382262996941896% przypadkow
# przeliczono 0.3859035969127712% przypadkow
# przeliczono 0.3895441968836464% przypadkow
# przeliczono 0.39318479685452157% przypadkow
# przeliczono 0.3968253968253968% przypadkow
# przeliczono 0.40046599679627204% przypadkow
# przeliczono 0.4041065967671472% przypadkow
# przeliczono 0.40774719673802245% przypadkow
# przeliczono 0.4113877967088976% przypadkow
# przeliczono 0.4150283966797728% przypadkow
# przeliczono 0.41866899665064805% przypadkow
# przeliczono 0.42230959662152323% przypadkow
# przeliczono 0.42595019659239847% przypadkow
# przeliczono 0.4295907965632736% przypadkow
# przeliczono 0.4332313965341488% przypadkow
# przeliczono 0.436871996505024% przypadkow
# przeliczono 0.44051259647589924% przypadkow
# przeliczono 0.4441531964467745% przypadkow
# przeliczono 0.4477937964176496% przypadkow
# przeliczono 0.45143439638852484% przypadkow
# przeliczono 0.4550749963594% przypadkow
# przeliczono 0.45871559633027525% przypadkow
# przeliczono 0.4623561963011504% przypadkow
# przeliczono 0.4659967962720256% przypadkow
# przeliczono 0.4696373962429008% przypadkow
# przeliczono 0.47327799621377603% przypadkow
# przeliczono 0.47691859618465127% przypadkow
# przeliczono 0.4805591961555264% przypadkow
# przeliczono 0.4841997961264016% przypadkow
# przeliczono 0.4878403960972768% przypadkow
# przeliczono 0.49148099606815204% przypadkow
# przeliczono 0.4951215960390273% przypadkow
# przeliczono 0.4987621960099024% przypadkow
# przeliczono 0.5024027959807776% przypadkow
# przeliczono 0.5060433959516528% przypadkow
# przeliczono 0.509683995922528% przypadkow
# przeliczono 0.5133245958934033% przypadkow
# przeliczono 0.5169651958642784% przypadkow
# przeliczono 0.5206057958351537% przypadkow
# przeliczono 0.5242463958060288% przypadkow
# przeliczono 0.527886995776904% przypadkow
# przeliczono 0.5315275957477793% przypadkow
# przeliczono 0.5351681957186544% przypadkow
# przeliczono 0.5388087956895297% przypadkow
# przeliczono 0.5424493956604048% przypadkow
# przeliczono 0.54608999563128% przypadkow
# przeliczono 0.5497305956021552% przypadkow
# przeliczono 0.5533711955730304% przypadkow
# przeliczono 0.5570117955439057% przypadkow
# przeliczono 0.5606523955147809% przypadkow
# przeliczono 0.564292995485656% przypadkow
# przeliczono 0.5679335954565312% przypadkow
# przeliczono 0.5715741954274064% przypadkow
# przeliczono 0.5752147953982817% przypadkow
# przeliczono 0.5788553953691569% przypadkow
# przeliczono 0.582495995340032% przypadkow
# przeliczono 0.5861365953109072% przypadkow
# przeliczono 0.5897771952817824% przypadkow
# przeliczono 0.5934177952526576% przypadkow
# przeliczono 0.5970583952235329% przypadkow
# przeliczono 0.6006989951944081% przypadkow
# przeliczono 0.6043395951652832% przypadkow
# przeliczono 0.6079801951361584% przypadkow
# przeliczono 0.6116207951070336% przypadkow
# przeliczono 0.6152613950779089% przypadkow
# przeliczono 0.6189019950487841% przypadkow
# przeliczono 0.6225425950196593% przypadkow
# przeliczono 0.6261831949905344% przypadkow
# przeliczono 0.6298237949614096% przypadkow
# przeliczono 0.6334643949322849% przypadkow
# przeliczono 0.63710499490316% przypadkow
# przeliczono 0.6407455948740353% przypadkow
# przeliczono 0.6443861948449104% przypadkow
# przeliczono 0.6480267948157856% przypadkow
# przeliczono 0.6516673947866609% przypadkow
# przeliczono 0.655307994757536% przypadkow
# przeliczono 0.6589485947284113% przypadkow
# przeliczono 0.6625891946992865% przypadkow
# przeliczono 0.6662297946701616% przypadkow
# przeliczono 0.6698703946410369% przypadkow
# przeliczono 0.673510994611912% przypadkow
# przeliczono 0.6771515945827872% przypadkow
# przeliczono 0.6807921945536625% przypadkow
# przeliczono 0.6844327945245376% przypadkow
# przeliczono 0.6880733944954129% przypadkow
# przeliczono 0.691713994466288% przypadkow
# przeliczono 0.6953545944371632% przypadkow
# przeliczono 0.6989951944080385% przypadkow
# przeliczono 0.7026357943789137% przypadkow
# przeliczono 0.7062763943497888% przypadkow
# przeliczono 0.709916994320664% przypadkow
# przeliczono 0.7135575942915392% przypadkow
# przeliczono 0.7171981942624145% przypadkow
# przeliczono 0.7208387942332897% przypadkow
# przeliczono 0.7244793942041649% przypadkow
# przeliczono 0.72811999417504% przypadkow
# przeliczono 0.7317605941459152% przypadkow
# przeliczono 0.7354011941167905% przypadkow
# przeliczono 0.7390417940876657% przypadkow
# przeliczono 0.7426823940585409% przypadkow
# przeliczono 0.746322994029416% przypadkow
# przeliczono 0.7499635940002912% przypadkow
# przeliczono 0.7536041939711665% przypadkow
# przeliczono 0.7572447939420417% przypadkow
# przeliczono 0.7608853939129168% przypadkow
# przeliczono 0.764525993883792% przypadkow
# przeliczono 0.7681665938546672% przypadkow
# przeliczono 0.7718071938255424% przypadkow
# przeliczono 0.7754477937964177% przypadkow
# przeliczono 0.7790883937672928% przypadkow
# przeliczono 0.7827289937381681% przypadkow
# przeliczono 0.7863695937090431% przypadkow
# przeliczono 0.7900101936799184% przypadkow
# przeliczono 0.7936507936507936% przypadkow
# przeliczono 0.7972913936216689% przypadkow
# przeliczono 0.8009319935925441% przypadkow
# przeliczono 0.8045725935634191% przypadkow
# przeliczono 0.8082131935342944% przypadkow
# przeliczono 0.8118537935051696% przypadkow
# przeliczono 0.8154943934760449% przypadkow
# przeliczono 0.8191349934469201% przypadkow
# przeliczono 0.8227755934177952% przypadkow
# przeliczono 0.8264161933886705% przypadkow
# przeliczono 0.8300567933595456% przypadkow
# przeliczono 0.8336973933304209% przypadkow
# przeliczono 0.8373379933012961% przypadkow
# przeliczono 0.8409785932721712% przypadkow
# przeliczono 0.8446191932430465% przypadkow
# przeliczono 0.8482597932139216% przypadkow
# przeliczono 0.8519003931847969% przypadkow
# przeliczono 0.8555409931556721% przypadkow
# przeliczono 0.8591815931265472% przypadkow
# przeliczono 0.8628221930974225% przypadkow
# przeliczono 0.8664627930682977% przypadkow
# przeliczono 0.870103393039173% przypadkow
# przeliczono 0.873743993010048% przypadkow
# przeliczono 0.8773845929809232% przypadkow
# przeliczono 0.8810251929517985% przypadkow
# przeliczono 0.8846657929226737% przypadkow
# przeliczono 0.888306392893549% przypadkow
# przeliczono 0.891946992864424% przypadkow
# przeliczono 0.8955875928352992% przypadkow
# przeliczono 0.8992281928061745% przypadkow
# przeliczono 0.9028687927770497% przypadkow
# przeliczono 0.906509392747925% przypadkow
# przeliczono 0.9101499927188% przypadkow
# przeliczono 0.9137905926896752% przypadkow
# przeliczono 0.9174311926605505% przypadkow
# przeliczono 0.9210717926314257% przypadkow
# przeliczono 0.9247123926023008% przypadkow
# przeliczono 0.928352992573176% przypadkow
# przeliczono 0.9319935925440512% przypadkow
# przeliczono 0.9356341925149265% przypadkow
# przeliczono 0.9392747924858016% przypadkow
# przeliczono 0.9429153924566768% przypadkow
# przeliczono 0.9465559924275521% przypadkow
# przeliczono 0.9501965923984272% przypadkow
# przeliczono 0.9538371923693025% przypadkow
# przeliczono 0.9574777923401776% przypadkow
# przeliczono 0.9611183923110528% przypadkow
# przeliczono 0.9647589922819281% przypadkow
# przeliczono 0.9683995922528033% przypadkow
# przeliczono 0.9720401922236785% przypadkow
# przeliczono 0.9756807921945536% przypadkow
# przeliczono 0.9793213921654288% przypadkow
# przeliczono 0.9829619921363041% przypadkow
# przeliczono 0.9866025921071793% przypadkow
# przeliczono 0.9902431920780546% przypadkow
# przeliczono 0.9938837920489296% przypadkow
# przeliczono 0.9975243920198048% przypadkow
# przeliczono 1.00116499199068% przypadkow
# przeliczono 1.0048055919615553% przypadkow
# przeliczono 1.0084461919324306% przypadkow
# przeliczono 1.0120867919033056% przypadkow
# przeliczono 1.0157273918741807% przypadkow
# przeliczono 1.019367991845056% przypadkow
# przeliczono 1.0230085918159313% przypadkow
# przeliczono 1.0266491917868066% przypadkow
# przeliczono 1.0302897917576816% przypadkow
# przeliczono 1.0339303917285567% przypadkow
# przeliczono 1.037570991699432% przypadkow
# przeliczono 1.0412115916703073% przypadkow
# przeliczono 1.0448521916411826% przypadkow
# przeliczono 1.0484927916120577% przypadkow
# przeliczono 1.0521333915829327% przypadkow
# przeliczono 1.055773991553808% przypadkow
# przeliczono 1.0594145915246833% przypadkow
# przeliczono 1.0630551914955586% przypadkow
# przeliczono 1.0666957914664337% przypadkow
# przeliczono 1.0703363914373087% przypadkow
# przeliczono 1.073976991408184% przypadkow
# przeliczono 1.0776175913790593% przypadkow
# przeliczono 1.0812581913499346% przypadkow
# przeliczono 1.0848987913208097% przypadkow
# przeliczono 1.0885393912916848% przypadkow
# przeliczono 1.09217999126256% przypadkow
# przeliczono 1.0958205912334353% przypadkow
# przeliczono 1.0994611912043104% przypadkow
# przeliczono 1.1031017911751857% przypadkow
# przeliczono 1.1067423911460608% przypadkow
# przeliczono 1.110382991116936% przypadkow
# przeliczono 1.1140235910878113% przypadkow
# przeliczono 1.1176641910586864% przypadkow
# przeliczono 1.1213047910295617% przypadkow
# przeliczono 1.1249453910004368% przypadkow
# przeliczono 1.128585990971312% przypadkow
# przeliczono 1.1322265909421874% przypadkow
# przeliczono 1.1358671909130624% przypadkow
# przeliczono 1.1395077908839377% przypadkow
# przeliczono 1.1431483908548128% przypadkow
# przeliczono 1.146788990825688% przypadkow
# przeliczono 1.1504295907965634% przypadkow
# przeliczono 1.1540701907674384% przypadkow
# przeliczono 1.1577107907383137% przypadkow
# przeliczono 1.1613513907091888% przypadkow
# przeliczono 1.164991990680064% przypadkow
# przeliczono 1.1686325906509394% przypadkow
# przeliczono 1.1722731906218145% przypadkow
# przeliczono 1.1759137905926897% przypadkow
# przeliczono 1.1795543905635648% przypadkow
# przeliczono 1.18319499053444% przypadkow
# przeliczono 1.1868355905053152% przypadkow
# przeliczono 1.1904761904761905% przypadkow
# przeliczono 1.1941167904470658% przypadkow
# przeliczono 1.1977573904179408% przypadkow
# przeliczono 1.2013979903888161% przypadkow
# przeliczono 1.2050385903596912% przypadkow
# przeliczono 1.2086791903305665% przypadkow
# przeliczono 1.2123197903014418% przypadkow
# przeliczono 1.2159603902723168% przypadkow
# przeliczono 1.2196009902431921% przypadkow
# przeliczono 1.2232415902140672% przypadkow
# przeliczono 1.2268821901849425% przypadkow
# przeliczono 1.2305227901558178% przypadkow
# przeliczono 1.2341633901266928% przypadkow
# przeliczono 1.2378039900975681% przypadkow
# przeliczono 1.2414445900684432% przypadkow
# przeliczono 1.2450851900393185% przypadkow
# przeliczono 1.2487257900101938% przypadkow
# przeliczono 1.2523663899810689% przypadkow
# przeliczono 1.2560069899519442% przypadkow
# przeliczono 1.2596475899228192% przypadkow
# przeliczono 1.2632881898936945% przypadkow
# przeliczono 1.2669287898645698% przypadkow
# przeliczono 1.2705693898354449% przypadkow
# przeliczono 1.27420998980632% przypadkow
# przeliczono 1.2778505897771952% przypadkow
# przeliczono 1.2814911897480705% przypadkow
# przeliczono 1.2851317897189458% przypadkow
# przeliczono 1.2887723896898209% przypadkow
# przeliczono 1.292412989660696% przypadkow
# przeliczono 1.2960535896315712% przypadkow
# przeliczono 1.2996941896024465% przypadkow
# przeliczono 1.3033347895733218% przypadkow
# przeliczono 1.306975389544197% przypadkow
# przeliczono 1.310615989515072% przypadkow
# przeliczono 1.3142565894859473% przypadkow
# przeliczono 1.3178971894568225% przypadkow
# przeliczono 1.3215377894276978% przypadkow
# przeliczono 1.325178389398573% przypadkow
# przeliczono 1.328818989369448% przypadkow
# przeliczono 1.3324595893403233% przypadkow
# przeliczono 1.3361001893111983% przypadkow
# przeliczono 1.3397407892820739% przypadkow
# przeliczono 1.343381389252949% przypadkow
# przeliczono 1.347021989223824% przypadkow
# przeliczono 1.3506625891946993% przypadkow
# przeliczono 1.3543031891655744% przypadkow
# przeliczono 1.3579437891364499% przypadkow
# przeliczono 1.361584389107325% przypadkow
# przeliczono 1.3652249890782% przypadkow
# przeliczono 1.3688655890490753% przypadkow
# przeliczono 1.3725061890199504% przypadkow
# przeliczono 1.3761467889908259% przypadkow
# przeliczono 1.379787388961701% przypadkow
# przeliczono 1.383427988932576% przypadkow
# przeliczono 1.3870685889034513% przypadkow
# przeliczono 1.3907091888743264% przypadkow
# przeliczono 1.3943497888452017% przypadkow
# przeliczono 1.397990388816077% przypadkow
# przeliczono 1.401630988786952% przypadkow
# przeliczono 1.4052715887578273% przypadkow
# przeliczono 1.4089121887287024% przypadkow
# przeliczono 1.4125527886995777% przypadkow
# przeliczono 1.416193388670453% przypadkow
# przeliczono 1.419833988641328% przypadkow
# przeliczono 1.4234745886122033% przypadkow
# przeliczono 1.4271151885830784% przypadkow
# przeliczono 1.4307557885539537% przypadkow
# przeliczono 1.434396388524829% przypadkow
# przeliczono 1.438036988495704% przypadkow
# przeliczono 1.4416775884665793% przypadkow
# przeliczono 1.4453181884374544% przypadkow
# przeliczono 1.4489587884083297% przypadkow
# przeliczono 1.452599388379205% przypadkow
# przeliczono 1.45623998835008% przypadkow
# przeliczono 1.4598805883209554% przypadkow
# przeliczono 1.4635211882918304% przypadkow
# przeliczono 1.4671617882627057% przypadkow
# przeliczono 1.470802388233581% przypadkow
# przeliczono 1.474442988204456% przypadkow
# przeliczono 1.4780835881753314% przypadkow
# przeliczono 1.4817241881462064% przypadkow
# przeliczono 1.4853647881170817% przypadkow
# przeliczono 1.489005388087957% przypadkow
# przeliczono 1.492645988058832% przypadkow
# przeliczono 1.4962865880297074% przypadkow
# przeliczono 1.4999271880005824% przypadkow
# przeliczono 1.5035677879714577% przypadkow
# przeliczono 1.507208387942333% przypadkow
# przeliczono 1.510848987913208% przypadkow
# przeliczono 1.5144895878840834% przypadkow
# przeliczono 1.5181301878549585% przypadkow
# przeliczono 1.5217707878258335% przypadkow
# przeliczono 1.525411387796709% przypadkow
# przeliczono 1.529051987767584% przypadkow
# przeliczono 1.5326925877384594% przypadkow
# przeliczono 1.5363331877093345% przypadkow
# przeliczono 1.5399737876802095% przypadkow
# przeliczono 1.5436143876510848% przypadkow
# przeliczono 1.5472549876219601% przypadkow
# przeliczono 1.5508955875928354% przypadkow
# przeliczono 1.5545361875637105% przypadkow
# przeliczono 1.5581767875345856% przypadkow
# przeliczono 1.5618173875054608% przypadkow
# przeliczono 1.5654579874763361% przypadkow
# przeliczono 1.5690985874472114% przypadkow
# przeliczono 1.5727391874180863% przypadkow
# przeliczono 1.5763797873889616% przypadkow
# przeliczono 1.5800203873598369% przypadkow
# przeliczono 1.5836609873307124% przypadkow
# przeliczono 1.5873015873015872% przypadkow
# przeliczono 1.5909421872724625% przypadkow
# przeliczono 1.5945827872433378% przypadkow
# przeliczono 1.5982233872142129% przypadkow
# przeliczono 1.6018639871850882% przypadkow
# przeliczono 1.6055045871559634% przypadkow
# przeliczono 1.6091451871268383% przypadkow
# przeliczono 1.6127857870977136% przypadkow
# przeliczono 1.6164263870685889% przypadkow
# przeliczono 1.6200669870394642% przypadkow
# przeliczono 1.6237075870103392% przypadkow
# przeliczono 1.6273481869812145% przypadkow
# przeliczono 1.6309887869520898% przypadkow
# przeliczono 1.6346293869229649% przypadkow
# przeliczono 1.6382699868938402% przypadkow
# przeliczono 1.6419105868647155% przypadkow
# przeliczono 1.6455511868355903% przypadkow
# przeliczono 1.6491917868064656% przypadkow
# przeliczono 1.652832386777341% przypadkow
# przeliczono 1.6564729867482162% przypadkow
# przeliczono 1.6601135867190913% przypadkow
# przeliczono 1.6637541866899666% przypadkow
# przeliczono 1.6673947866608418% przypadkow
# przeliczono 1.6710353866317167% przypadkow
# przeliczono 1.6746759866025922% przypadkow
# przeliczono 1.6783165865734675% przypadkow
# przeliczono 1.6819571865443423% przypadkow
# przeliczono 1.6855977865152176% przypadkow
# przeliczono 1.689238386486093% przypadkow
# przeliczono 1.692878986456968% przypadkow
# przeliczono 1.6965195864278433% przypadkow
# przeliczono 1.7001601863987186% przypadkow
# przeliczono 1.7038007863695939% przypadkow
# przeliczono 1.7074413863404687% przypadkow
# przeliczono 1.7110819863113442% przypadkow
# przeliczono 1.7147225862822195% przypadkow
# przeliczono 1.7183631862530944% przypadkow
# przeliczono 1.7220037862239697% przypadkow
# przeliczono 1.725644386194845% przypadkow
# przeliczono 1.72928498616572% przypadkow
# przeliczono 1.7329255861365953% przypadkow
# przeliczono 1.7365661861074706% przypadkow
# przeliczono 1.740206786078346% przypadkow
# przeliczono 1.7438473860492207% przypadkow
# przeliczono 1.747487986020096% przypadkow
# przeliczono 1.7511285859909713% przypadkow
# przeliczono 1.7547691859618464% przypadkow
# przeliczono 1.7584097859327217% przypadkow
# przeliczono 1.762050385903597% przypadkow
# przeliczono 1.765690985874472% przypadkow
# przeliczono 1.7693315858453473% przypadkow
# przeliczono 1.7729721858162226% przypadkow
# przeliczono 1.776612785787098% przypadkow
# przeliczono 1.7802533857579728% przypadkow
# przeliczono 1.783893985728848% przypadkow
# przeliczono 1.7875345856997233% przypadkow
# przeliczono 1.7911751856705984% przypadkow
# przeliczono 1.7948157856414737% przypadkow
# przeliczono 1.798456385612349% przypadkow
# przeliczono 1.802096985583224% przypadkow
# przeliczono 1.8057375855540994% przypadkow
# przeliczono 1.8093781855249746% przypadkow
# przeliczono 1.81301878549585% przypadkow
# przeliczono 1.8166593854667248% przypadkow
# przeliczono 1.8202999854376% przypadkow
# przeliczono 1.8239405854084754% przypadkow
# przeliczono 1.8275811853793504% przypadkow
# przeliczono 1.8312217853502257% przypadkow
# przeliczono 1.834862385321101% przypadkow
# przeliczono 1.838502985291976% przypadkow
# przeliczono 1.8421435852628514% przypadkow
# przeliczono 1.8457841852337267% przypadkow
# przeliczono 1.8494247852046015% przypadkow
# przeliczono 1.8530653851754768% przypadkow
# przeliczono 1.856705985146352% przypadkow
# przeliczono 1.8603465851172274% przypadkow
# przeliczono 1.8639871850881025% przypadkow
# przeliczono 1.8676277850589778% przypadkow
# przeliczono 1.871268385029853% przypadkow
# przeliczono 1.874908985000728% przypadkow
# przeliczono 1.8785495849716032% przypadkow
# przeliczono 1.8821901849424787% przypadkow
# przeliczono 1.8858307849133535% przypadkow
# przeliczono 1.8894713848842288% przypadkow
# przeliczono 1.8931119848551041% przypadkow
# przeliczono 1.8967525848259794% przypadkow
# przeliczono 1.9003931847968545% przypadkow
# przeliczono 1.9040337847677298% przypadkow
# przeliczono 1.907674384738605% przypadkow
# przeliczono 1.91131498470948% przypadkow
# przeliczono 1.9149555846803552% przypadkow
# przeliczono 1.9185961846512307% przypadkow
# przeliczono 1.9222367846221056% przypadkow
# przeliczono 1.9258773845929809% przypadkow
# przeliczono 1.9295179845638561% przypadkow
# przeliczono 1.9331585845347314% przypadkow
# przeliczono 1.9367991845056065% przypadkow
# przeliczono 1.9404397844764818% przypadkow
# przeliczono 1.944080384447357% przypadkow
# przeliczono 1.947720984418232% przypadkow
# przeliczono 1.9513615843891072% przypadkow
# przeliczono 1.9550021843599825% przypadkow
# przeliczono 1.9586427843308576% przypadkow
# przeliczono 1.9622833843017329% przypadkow
# przeliczono 1.9659239842726082% przypadkow
# przeliczono 1.9695645842434835% przypadkow
# przeliczono 1.9732051842143585% przypadkow
# przeliczono 1.9768457841852338% przypadkow
# przeliczono 1.9804863841561091% przypadkow
# przeliczono 1.984126984126984% przypadkow
# przeliczono 1.9877675840978593% przypadkow
# przeliczono 1.9914081840687345% przypadkow
# przeliczono 1.9950487840396096% przypadkow
# przeliczono 1.998689384010485% przypadkow
# przeliczono 2.00232998398136% przypadkow
# przeliczono 2.0059705839522355% przypadkow
# przeliczono 2.0096111839231106% przypadkow
# przeliczono 2.0132517838939856% przypadkow
# przeliczono 2.016892383864861% przypadkow
# przeliczono 2.020532983835736% przypadkow
# przeliczono 2.0241735838066113% przypadkow
# przeliczono 2.027814183777487% przypadkow
# przeliczono 2.0314547837483614% przypadkow
# przeliczono 2.035095383719237% przypadkow
# przeliczono 2.038735983690112% przypadkow
# przeliczono 2.042376583660987% przypadkow
# przeliczono 2.0460171836318626% przypadkow
# przeliczono 2.0496577836027376% przypadkow
# przeliczono 2.053298383573613% przypadkow
# przeliczono 2.0569389835444882% przypadkow
# przeliczono 2.0605795835153633% przypadkow
# przeliczono 2.064220183486239% przypadkow
# przeliczono 2.0678607834571134% przypadkow
# przeliczono 2.071501383427989% przypadkow
# przeliczono 2.075141983398864% przypadkow
# przeliczono 2.078782583369739% przypadkow
# przeliczono 2.0824231833406146% przypadkow
# przeliczono 2.0860637833114897% przypadkow
# przeliczono 2.089704383282365% przypadkow
# przeliczono 2.0933449832532403% przypadkow
# przeliczono 2.0969855832241153% przypadkow
# przeliczono 2.100626183194991% przypadkow
# przeliczono 2.1042667831658655% przypadkow
# przeliczono 2.107907383136741% przypadkow
# przeliczono 2.111547983107616% przypadkow
# przeliczono 2.115188583078491% przypadkow
# przeliczono 2.1188291830493666% przypadkow
# przeliczono 2.1224697830202417% przypadkow
# przeliczono 2.126110382991117% przypadkow
# przeliczono 2.1297509829619923% przypadkow
# przeliczono 2.1333915829328673% przypadkow
# przeliczono 2.137032182903743% przypadkow
# przeliczono 2.1406727828746175% przypadkow
# przeliczono 2.144313382845493% przypadkow
# przeliczono 2.147953982816368% przypadkow
# przeliczono 2.151594582787243% przypadkow
# przeliczono 2.1552351827581187% przypadkow
# przeliczono 2.1588757827289937% przypadkow
# przeliczono 2.1625163826998692% przypadkow
# przeliczono 2.166156982670744% przypadkow
# przeliczono 2.1697975826416194% przypadkow
# przeliczono 2.173438182612495% przypadkow
# przeliczono 2.1770787825833695% przypadkow
# przeliczono 2.180719382554245% przypadkow
# przeliczono 2.18435998252512% przypadkow
# przeliczono 2.188000582495995% przypadkow
# przeliczono 2.1916411824668707% przypadkow
# przeliczono 2.1952817824377457% przypadkow
# przeliczono 2.198922382408621% przypadkow
# przeliczono 2.202562982379496% przypadkow
# przeliczono 2.2062035823503714% przypadkow
# przeliczono 2.2098441823212465% przypadkow
# przeliczono 2.2134847822921215% przypadkow
# przeliczono 2.217125382262997% przypadkow
# przeliczono 2.220765982233872% przypadkow
# przeliczono 2.224406582204747% przypadkow
# przeliczono 2.2280471821756227% przypadkow
# przeliczono 2.2316877821464978% przypadkow
# przeliczono 2.235328382117373% przypadkow
# przeliczono 2.238968982088248% przypadkow
# przeliczono 2.2426095820591234% przypadkow
# przeliczono 2.2462501820299985% przypadkow
# przeliczono 2.2498907820008736% przypadkow
# przeliczono 2.253531381971749% przypadkow
# przeliczono 2.257171981942624% przypadkow
# przeliczono 2.260812581913499% przypadkow
# przeliczono 2.2644531818843747% przypadkow
# przeliczono 2.26809378185525% przypadkow
# przeliczono 2.271734381826125% przypadkow
# przeliczono 2.275374981797% przypadkow
# przeliczono 2.2790155817678754% przypadkow
# przeliczono 2.2826561817387505% przypadkow
# przeliczono 2.2862967817096256% przypadkow
# przeliczono 2.289937381680501% przypadkow
# przeliczono 2.293577981651376% przypadkow
# przeliczono 2.2972185816222512% przypadkow
# przeliczono 2.3008591815931267% przypadkow
# przeliczono 2.304499781564002% przypadkow
# przeliczono 2.308140381534877% przypadkow
# przeliczono 2.311780981505752% przypadkow
# przeliczono 2.3154215814766275% przypadkow
# przeliczono 2.3190621814475025% przypadkow
# przeliczono 2.3227027814183776% przypadkow
# przeliczono 2.326343381389253% przypadkow
# przeliczono 2.329983981360128% przypadkow
# przeliczono 2.3336245813310033% przypadkow
# przeliczono 2.3372651813018788% przypadkow
# przeliczono 2.340905781272754% przypadkow
# przeliczono 2.344546381243629% przypadkow
# przeliczono 2.348186981214504% przypadkow
# przeliczono 2.3518275811853795% przypadkow
# przeliczono 2.3554681811562546% przypadkow
# przeliczono 2.3591087811271296% przypadkow
# przeliczono 2.362749381098005% przypadkow
# przeliczono 2.36638998106888% przypadkow
# przeliczono 2.3700305810397553% przypadkow
# przeliczono 2.3736711810106303% przypadkow
# przeliczono 2.377311780981506% przypadkow
# przeliczono 2.380952380952381% przypadkow
# przeliczono 2.384592980923256% przypadkow
# przeliczono 2.3882335808941315% przypadkow
# przeliczono 2.3918741808650066% przypadkow
# przeliczono 2.3955147808358817% przypadkow
# przeliczono 2.399155380806757% przypadkow
# przeliczono 2.4027959807776322% przypadkow
# przeliczono 2.4064365807485073% przypadkow
# przeliczono 2.4100771807193824% przypadkow
# przeliczono 2.413717780690258% przypadkow
# przeliczono 2.417358380661133% przypadkow
# przeliczono 2.420998980632008% przypadkow
# przeliczono 2.4246395806028835% przypadkow
# przeliczono 2.4282801805737586% przypadkow
# przeliczono 2.4319207805446337% przypadkow
# przeliczono 2.435561380515509% przypadkow
# przeliczono 2.4392019804863843% przypadkow
# przeliczono 2.4428425804572593% przypadkow
# przeliczono 2.4464831804281344% przypadkow
# przeliczono 2.45012378039901% przypadkow
# przeliczono 2.453764380369885% przypadkow
# przeliczono 2.45740498034076% przypadkow
# przeliczono 2.4610455803116356% przypadkow
# przeliczono 2.46468618028251% przypadkow
# przeliczono 2.4683267802533857% przypadkow
# przeliczono 2.471967380224261% przypadkow
# przeliczono 2.4756079801951363% przypadkow
# przeliczono 2.4792485801660114% przypadkow
# przeliczono 2.4828891801368864% przypadkow
# przeliczono 2.486529780107762% przypadkow
# przeliczono 2.490170380078637% przypadkow
# przeliczono 2.493810980049512% przypadkow
# przeliczono 2.4974515800203876% przypadkow
# przeliczono 2.501092179991262% przypadkow
# przeliczono 2.5047327799621377% przypadkow
# przeliczono 2.5083733799330132% przypadkow
# przeliczono 2.5120139799038883% przypadkow
# przeliczono 2.5156545798747634% przypadkow
# przeliczono 2.5192951798456384% przypadkow
# przeliczono 2.522935779816514% przypadkow
# przeliczono 2.526576379787389% przypadkow
# przeliczono 2.530216979758264% przypadkow
# przeliczono 2.5338575797291396% przypadkow
# przeliczono 2.5374981797000142% przypadkow
# przeliczono 2.5411387796708897% przypadkow
# przeliczono 2.5447793796417653% przypadkow
# przeliczono 2.54841997961264% przypadkow
# przeliczono 2.5520605795835154% przypadkow
# przeliczono 2.5557011795543905% przypadkow
# przeliczono 2.559341779525266% przypadkow
# przeliczono 2.562982379496141% przypadkow
# przeliczono 2.566622979467016% przypadkow
# przeliczono 2.5702635794378916% przypadkow
# przeliczono 2.5739041794087663% przypadkow
# przeliczono 2.5775447793796418% przypadkow
# przeliczono 2.581185379350517% przypadkow
# przeliczono 2.584825979321392% przypadkow
# przeliczono 2.5884665792922674% przypadkow
# przeliczono 2.5921071792631425% przypadkow
# przeliczono 2.595747779234018% przypadkow
# przeliczono 2.599388379204893% przypadkow
# przeliczono 2.603028979175768% przypadkow
# przeliczono 2.6066695791466437% przypadkow
# przeliczono 2.6103101791175183% przypadkow
# przeliczono 2.613950779088394% przypadkow
# przeliczono 2.617591379059269% przypadkow
# przeliczono 2.621231979030144% przypadkow
# przeliczono 2.6248725790010194% przypadkow
# przeliczono 2.6285131789718945% przypadkow
# przeliczono 2.63215377894277% przypadkow
# przeliczono 2.635794378913645% przypadkow
# przeliczono 2.63943497888452% przypadkow
# przeliczono 2.6430755788553957% przypadkow
# przeliczono 2.6467161788262703% przypadkow
# przeliczono 2.650356778797146% przypadkow
# przeliczono 2.653997378768021% przypadkow
# przeliczono 2.657637978738896% przypadkow
# przeliczono 2.6612785787097715% przypadkow
# przeliczono 2.6649191786806465% przypadkow
# przeliczono 2.668559778651522% przypadkow
# przeliczono 2.6722003786223967% przypadkow
# przeliczono 2.675840978593272% przypadkow
# przeliczono 2.6794815785641477% przypadkow
# przeliczono 2.6831221785350223% przypadkow
# przeliczono 2.686762778505898% przypadkow
# przeliczono 2.690403378476773% przypadkow
# przeliczono 2.694043978447648% przypadkow
# przeliczono 2.6976845784185235% przypadkow
# przeliczono 2.7013251783893986% przypadkow
# przeliczono 2.7049657783602736% przypadkow
# przeliczono 2.7086063783311487% przypadkow
# przeliczono 2.712246978302024% przypadkow
# przeliczono 2.7158875782728997% przypadkow
# przeliczono 2.7195281782437744% przypadkow
# przeliczono 2.72316877821465% przypadkow
# przeliczono 2.726809378185525% przypadkow
# przeliczono 2.7304499781564% przypadkow
# przeliczono 2.7340905781272755% przypadkow
# przeliczono 2.7377311780981506% przypadkow
# przeliczono 2.7413717780690257% przypadkow
# przeliczono 2.7450123780399007% przypadkow
# przeliczono 2.7486529780107762% przypadkow
# przeliczono 2.7522935779816518% przypadkow
# przeliczono 2.7559341779525264% przypadkow
# przeliczono 2.759574777923402% przypadkow
# przeliczono 2.763215377894277% przypadkow
# przeliczono 2.766855977865152% przypadkow
# przeliczono 2.7704965778360275% przypadkow
# przeliczono 2.7741371778069026% przypadkow
# przeliczono 2.7777777777777777% przypadkow
# przeliczono 2.7814183777486527% przypadkow
# przeliczono 2.7850589777195283% przypadkow
# przeliczono 2.7886995776904033% przypadkow
# przeliczono 2.7923401776612784% przypadkow
# przeliczono 2.795980777632154% przypadkow
# przeliczono 2.799621377603029% przypadkow
# przeliczono 2.803261977573904% przypadkow
# przeliczono 2.8069025775447796% przypadkow
# przeliczono 2.8105431775156546% przypadkow
# przeliczono 2.8141837774865297% przypadkow
# przeliczono 2.8178243774574048% przypadkow
# przeliczono 2.8214649774282803% przypadkow
# przeliczono 2.8251055773991554% przypadkow
# przeliczono 2.8287461773700304% przypadkow
# przeliczono 2.832386777340906% przypadkow
# przeliczono 2.836027377311781% przypadkow
# przeliczono 2.839667977282656% przypadkow
# przeliczono 2.8433085772535316% przypadkow
# przeliczono 2.8469491772244067% przypadkow
# przeliczono 2.8505897771952817% przypadkow
# przeliczono 2.854230377166157% przypadkow
# przeliczono 2.8578709771370323% przypadkow
# przeliczono 2.8615115771079074% przypadkow
# przeliczono 2.8651521770787824% przypadkow
# przeliczono 2.868792777049658% przypadkow
# przeliczono 2.872433377020533% przypadkow
# przeliczono 2.876073976991408% przypadkow
# przeliczono 2.879714576962283% przypadkow
# przeliczono 2.8833551769331587% przypadkow
# przeliczono 2.8869957769040338% przypadkow
# przeliczono 2.890636376874909% przypadkow
# przeliczono 2.8942769768457843% przypadkow
# przeliczono 2.8979175768166594% przypadkow
# przeliczono 2.9015581767875345% przypadkow
# przeliczono 2.90519877675841% przypadkow
# przeliczono 2.908839376729285% przypadkow
# przeliczono 2.91247997670016% przypadkow
# przeliczono 2.916120576671035% przypadkow
# przeliczono 2.9197611766419107% przypadkow
# przeliczono 2.9234017766127858% przypadkow
# przeliczono 2.927042376583661% przypadkow
# przeliczono 2.9306829765545364% przypadkow
# przeliczono 2.9343235765254114% przypadkow
# przeliczono 2.9379641764962865% przypadkow
# przeliczono 2.941604776467162% przypadkow
# przeliczono 2.945245376438037% przypadkow
# przeliczono 2.948885976408912% przypadkow
# przeliczono 2.952526576379787% przypadkow
# przeliczono 2.9561671763506627% przypadkow
# przeliczono 2.959807776321538% przypadkow
# przeliczono 2.963448376292413% przypadkow
# przeliczono 2.9670889762632884% przypadkow
# przeliczono 2.9707295762341634% przypadkow
# przeliczono 2.9743701762050385% przypadkow
# przeliczono 2.978010776175914% przypadkow
# przeliczono 2.981651376146789% przypadkow
# przeliczono 2.985291976117664% przypadkow
# przeliczono 2.9889325760885392% przypadkow
# przeliczono 2.9925731760594148% przypadkow
# przeliczono 2.99621377603029% przypadkow
# przeliczono 2.999854376001165% przypadkow
# przeliczono 3.0034949759720404% przypadkow
# przeliczono 3.0071355759429155% przypadkow
# przeliczono 3.0107761759137905% przypadkow
# przeliczono 3.014416775884666% przypadkow
# przeliczono 3.018057375855541% przypadkow
# przeliczono 3.021697975826416% przypadkow
# przeliczono 3.0253385757972913% przypadkow
# przeliczono 3.0289791757681668% przypadkow
# przeliczono 3.032619775739042% przypadkow
# przeliczono 3.036260375709917% przypadkow
# przeliczono 3.0399009756807924% przypadkow
# przeliczono 3.043541575651667% przypadkow
# przeliczono 3.0471821756225426% przypadkow
# przeliczono 3.050822775593418% przypadkow
# przeliczono 3.0544633755642927% przypadkow
# przeliczono 3.058103975535168% przypadkow
# przeliczono 3.0617445755060433% przypadkow
# przeliczono 3.065385175476919% przypadkow
# przeliczono 3.069025775447794% przypadkow
# przeliczono 3.072666375418669% przypadkow
# przeliczono 3.0763069753895445% przypadkow
# przeliczono 3.079947575360419% przypadkow
# przeliczono 3.0835881753312946% przypadkow
# przeliczono 3.0872287753021697% przypadkow
# przeliczono 3.0908693752730447% przypadkow
# przeliczono 3.0945099752439202% przypadkow
# przeliczono 3.0981505752147953% przypadkow
# przeliczono 3.101791175185671% przypadkow
# przeliczono 3.105431775156546% przypadkow
# przeliczono 3.109072375127421% przypadkow
# przeliczono 3.1127129750982965% przypadkow
# przeliczono 3.116353575069171% przypadkow
# przeliczono 3.1199941750400466% przypadkow
# przeliczono 3.1236347750109217% przypadkow
# przeliczono 3.127275374981797% przypadkow
# przeliczono 3.1309159749526723% przypadkow
# przeliczono 3.134556574923547% przypadkow
# przeliczono 3.138197174894423% przypadkow
# przeliczono 3.141837774865298% przypadkow
# przeliczono 3.1454783748361725% przypadkow
# przeliczono 3.1491189748070485% przypadkow
# przeliczono 3.152759574777923% przypadkow
# przeliczono 3.156400174748799% przypadkow
# przeliczono 3.1600407747196737% przypadkow
# przeliczono 3.1636813746905488% przypadkow
# przeliczono 3.1673219746614247% przypadkow
# przeliczono 3.1709625746322994% przypadkow
# przeliczono 3.1746031746031744% przypadkow
# przeliczono 3.17824377457405% przypadkow
# przeliczono 3.181884374544925% przypadkow
# przeliczono 3.1855249745158% przypadkow
# przeliczono 3.1891655744866756% przypadkow
# przeliczono 3.1928061744575507% przypadkow
# przeliczono 3.1964467744284257% przypadkow
# przeliczono 3.2000873743993012% przypadkow
# przeliczono 3.2037279743701763% przypadkow
# przeliczono 3.207368574341051% przypadkow
# przeliczono 3.211009174311927% przypadkow
# przeliczono 3.214649774282802% przypadkow
# przeliczono 3.2182903742536766% przypadkow
# przeliczono 3.2219309742245525% przypadkow
# przeliczono 3.225571574195427% przypadkow
# przeliczono 3.2292121741663022% przypadkow
# przeliczono 3.2328527741371778% przypadkow
# przeliczono 3.236493374108053% przypadkow
# przeliczono 3.2401339740789283% przypadkow
# przeliczono 3.2437745740498034% przypadkow
# przeliczono 3.2474151740206785% przypadkow
# przeliczono 3.251055773991554% przypadkow
# przeliczono 3.254696373962429% przypadkow
# przeliczono 3.258336973933304% przypadkow
# przeliczono 3.2619775739041796% przypadkow
# przeliczono 3.2656181738750547% przypadkow
# przeliczono 3.2692587738459298% przypadkow
# przeliczono 3.2728993738168053% przypadkow
# przeliczono 3.2765399737876804% przypadkow
# przeliczono 3.280180573758555% przypadkow
# przeliczono 3.283821173729431% przypadkow
# przeliczono 3.2874617737003056% przypadkow
# przeliczono 3.2911023736711806% przypadkow
# przeliczono 3.294742973642056% przypadkow
# przeliczono 3.298383573612931% przypadkow
# przeliczono 3.3020241735838063% przypadkow
# przeliczono 3.305664773554682% przypadkow
# przeliczono 3.309305373525557% przypadkow
# przeliczono 3.3129459734964324% przypadkow
# przeliczono 3.3165865734673075% przypadkow
# przeliczono 3.3202271734381825% przypadkow
# przeliczono 3.323867773409058% przypadkow
# przeliczono 3.327508373379933% przypadkow
# przeliczono 3.331148973350808% przypadkow
# przeliczono 3.3347895733216837% przypadkow
# przeliczono 3.3384301732925588% przypadkow
# przeliczono 3.3420707732634334% przypadkow
# przeliczono 3.3457113732343093% przypadkow
# przeliczono 3.3493519732051844% przypadkow
# przeliczono 3.352992573176059% przypadkow
# przeliczono 3.356633173146935% przypadkow
# przeliczono 3.3602737731178096% przypadkow
# przeliczono 3.3639143730886847% przypadkow
# przeliczono 3.36755497305956% przypadkow
# przeliczono 3.3711955730304353% przypadkow
# przeliczono 3.3748361730013103% przypadkow
# przeliczono 3.378476772972186% przypadkow
# przeliczono 3.382117372943061% przypadkow
# przeliczono 3.385757972913936% przypadkow
# przeliczono 3.3893985728848115% przypadkow
# przeliczono 3.3930391728556866% przypadkow
# przeliczono 3.396679772826562% przypadkow
# przeliczono 3.400320372797437% przypadkow
# przeliczono 3.403960972768312% przypadkow
# przeliczono 3.4076015727391877% przypadkow
# przeliczono 3.411242172710063% przypadkow
# przeliczono 3.4148827726809374% przypadkow
# przeliczono 3.4185233726518134% przypadkow
# przeliczono 3.4221639726226885% przypadkow
# przeliczono 3.425804572593563% przypadkow
# przeliczono 3.429445172564439% przypadkow
# przeliczono 3.4330857725353137% przypadkow
# przeliczono 3.4367263725061887% przypadkow
# przeliczono 3.4403669724770642% przypadkow
# przeliczono 3.4440075724479393% przypadkow
# przeliczono 3.4476481724188144% przypadkow
# przeliczono 3.45128877238969% przypadkow
# przeliczono 3.454929372360565% przypadkow
# przeliczono 3.45856997233144% przypadkow
# przeliczono 3.4622105723023155% przypadkow
# przeliczono 3.4658511722731906% przypadkow
# przeliczono 3.469491772244066% przypadkow
# przeliczono 3.473132372214941% przypadkow
# przeliczono 3.4767729721858163% przypadkow
# przeliczono 3.480413572156692% przypadkow
# przeliczono 3.484054172127567% przypadkow
# przeliczono 3.4876947720984415% przypadkow
# przeliczono 3.4913353720693174% przypadkow
# przeliczono 3.494975972040192% przypadkow
# przeliczono 3.498616572011067% przypadkow
# przeliczono 3.5022571719819426% przypadkow
# przeliczono 3.5058977719528177% przypadkow
# przeliczono 3.509538371923693% przypadkow
# przeliczono 3.5131789718945683% przypadkow
# przeliczono 3.5168195718654434% przypadkow
# przeliczono 3.5204601718363184% przypadkow
# przeliczono 3.524100771807194% przypadkow
# przeliczono 3.527741371778069% przypadkow
# przeliczono 3.531381971748944% przypadkow
# przeliczono 3.5350225717198196% przypadkow
# przeliczono 3.5386631716906947% przypadkow
# przeliczono 3.5423037716615693% przypadkow
# przeliczono 3.5459443716324452% przypadkow
# przeliczono 3.54958497160332% przypadkow
# przeliczono 3.553225571574196% przypadkow
# przeliczono 3.556866171545071% przypadkow
# przeliczono 3.5605067715159455% przypadkow
# przeliczono 3.5641473714868215% przypadkow
# przeliczono 3.567787971457696% przypadkow
# przeliczono 3.571428571428571% przypadkow
# przeliczono 3.5750691713994467% przypadkow
# przeliczono 3.5787097713703218% przypadkow
# przeliczono 3.582350371341197% przypadkow
# przeliczono 3.5859909713120723% przypadkow
# przeliczono 3.5896315712829474% przypadkow
# przeliczono 3.5932721712538225% przypadkow
# przeliczono 3.596912771224698% przypadkow
# przeliczono 3.600553371195573% przypadkow
# przeliczono 3.604193971166448% przypadkow
# przeliczono 3.6078345711373236% przypadkow
# przeliczono 3.6114751711081987% przypadkow
# przeliczono 3.6151157710790733% przypadkow
# przeliczono 3.6187563710499493% przypadkow
# przeliczono 3.622396971020824% przypadkow
# przeliczono 3.6260375709917% przypadkow
# przeliczono 3.629678170962575% przypadkow
# przeliczono 3.6333187709334496% przypadkow
# przeliczono 3.6369593709043255% przypadkow
# przeliczono 3.6405999708752% przypadkow
# przeliczono 3.6442405708460752% przypadkow
# przeliczono 3.6478811708169507% przypadkow
# przeliczono 3.651521770787826% przypadkow
# przeliczono 3.655162370758701% przypadkow
# przeliczono 3.6588029707295764% przypadkow
# przeliczono 3.6624435707004515% przypadkow
# przeliczono 3.6660841706713265% przypadkow
# przeliczono 3.669724770642202% przypadkow
# przeliczono 3.673365370613077% przypadkow
# przeliczono 3.677005970583952% przypadkow
# przeliczono 3.6806465705548277% przypadkow
# przeliczono 3.6842871705257028% przypadkow
# przeliczono 3.6879277704965774% przypadkow
# przeliczono 3.6915683704674533% przypadkow
# przeliczono 3.695208970438328% przypadkow
# przeliczono 3.698849570409203% przypadkow
# przeliczono 3.7024901703800785% przypadkow
# przeliczono 3.7061307703509536% przypadkow
# przeliczono 3.709771370321829% przypadkow
# przeliczono 3.713411970292704% przypadkow
# przeliczono 3.7170525702635793% przypadkow
# przeliczono 3.720693170234455% przypadkow
# przeliczono 3.72433377020533% przypadkow
# przeliczono 3.727974370176205% przypadkow
# przeliczono 3.7316149701470804% przypadkow
# przeliczono 3.7352555701179555% przypadkow
# przeliczono 3.7388961700888306% przypadkow
# przeliczono 3.742536770059706% przypadkow
# przeliczono 3.746177370030581% przypadkow
# przeliczono 3.749817970001456% przypadkow
# przeliczono 3.7534585699723317% przypadkow
# przeliczono 3.7570991699432064% przypadkow
# przeliczono 3.7607397699140814% przypadkow
# przeliczono 3.7643803698849574% przypadkow
# przeliczono 3.768020969855832% przypadkow
# przeliczono 3.771661569826707% przypadkow
# przeliczono 3.7753021697975826% przypadkow
# przeliczono 3.7789427697684577% przypadkow
# przeliczono 3.782583369739333% przypadkow
# przeliczono 3.7862239697102082% przypadkow
# przeliczono 3.7898645696810833% przypadkow
# przeliczono 3.793505169651959% przypadkow
# przeliczono 3.797145769622834% przypadkow
# przeliczono 3.800786369593709% przypadkow
# przeliczono 3.8044269695645845% przypadkow
# przeliczono 3.8080675695354596% przypadkow
# przeliczono 3.8117081695063346% przypadkow
# przeliczono 3.81534876947721% przypadkow
# przeliczono 3.818989369448085% przypadkow
# przeliczono 3.82262996941896% przypadkow
# przeliczono 3.826270569389836% przypadkow
# przeliczono 3.8299111693607104% przypadkow
# przeliczono 3.8335517693315855% przypadkow
# przeliczono 3.8371923693024614% przypadkow
# przeliczono 3.840832969273336% przypadkow
# przeliczono 3.844473569244211% przypadkow
# przeliczono 3.8481141692150866% przypadkow
# przeliczono 3.8517547691859617% przypadkow
# przeliczono 3.8553953691568372% przypadkow
# przeliczono 3.8590359691277123% przypadkow
# przeliczono 3.8626765690985874% przypadkow
# przeliczono 3.866317169069463% przypadkow
# przeliczono 3.869957769040338% przypadkow
# przeliczono 3.873598369011213% przypadkow
# przeliczono 3.8772389689820885% przypadkow
# przeliczono 3.8808795689529636% przypadkow
# przeliczono 3.8845201689238387% przypadkow
# przeliczono 3.888160768894714% przypadkow
# przeliczono 3.8918013688655893% przypadkow
# przeliczono 3.895441968836464% przypadkow
# przeliczono 3.89908256880734% przypadkow
# przeliczono 3.9027231687782145% przypadkow
# przeliczono 3.9063637687490895% przypadkow
# przeliczono 3.910004368719965% przypadkow
# przeliczono 3.91364496869084% przypadkow
# przeliczono 3.917285568661715% przypadkow
# przeliczono 3.9209261686325907% przypadkow
# przeliczono 3.9245667686034658% przypadkow
# przeliczono 3.928207368574341% przypadkow
# przeliczono 3.9318479685452163% przypadkow
# przeliczono 3.9354885685160914% przypadkow
# przeliczono 3.939129168486967% przypadkow
# przeliczono 3.942769768457842% przypadkow
# przeliczono 3.946410368428717% przypadkow
# przeliczono 3.9500509683995926% przypadkow
# przeliczono 3.9536915683704676% przypadkow
# przeliczono 3.9573321683413423% przypadkow
# przeliczono 3.9609727683122182% przypadkow
# przeliczono 3.964613368283093% przypadkow
# przeliczono 3.968253968253968% przypadkow
# przeliczono 3.971894568224844% przypadkow
# przeliczono 3.9755351681957185% przypadkow
# przeliczono 3.9791757681665936% przypadkow
# przeliczono 3.982816368137469% przypadkow
# przeliczono 3.986456968108344% przypadkow
# przeliczono 3.9900975680792192% przypadkow
# przeliczono 3.9937381680500947% przypadkow
# przeliczono 3.99737876802097% przypadkow
# przeliczono 4.001019367991844% przypadkow
# przeliczono 4.00465996796272% przypadkow
# przeliczono 4.0083005679335955% przypadkow
# przeliczono 4.011941167904471% przypadkow
# przeliczono 4.015581767875346% przypadkow
# przeliczono 4.019222367846221% przypadkow
# przeliczono 4.022862967817097% przypadkow
# przeliczono 4.026503567787971% przypadkow
# przeliczono 4.030144167758847% przypadkow
# przeliczono 4.033784767729722% przypadkow
# przeliczono 4.037425367700597% przypadkow
# przeliczono 4.041065967671472% przypadkow
# przeliczono 4.044706567642348% przypadkow
# przeliczono 4.0483471676132226% przypadkow
# przeliczono 4.051987767584098% przypadkow
# przeliczono 4.055628367554974% przypadkow
# przeliczono 4.059268967525848% przypadkow
# przeliczono 4.062909567496723% przypadkow
# przeliczono 4.066550167467599% przypadkow
# przeliczono 4.070190767438474% przypadkow
# przeliczono 4.0738313674093485% przypadkow
# przeliczono 4.077471967380224% przypadkow
# przeliczono 4.0811125673510995% przypadkow
# przeliczono 4.084753167321974% przypadkow
# przeliczono 4.08839376729285% przypadkow
# przeliczono 4.092034367263725% przypadkow
# przeliczono 4.095674967234601% przypadkow
# ...
# przeliczono 48.729430610164556% przypadkow
# przeliczono 48.73307121013543% przypadkow
# przeliczono 48.7367118101063% przypadkow
# przeliczono 48.74035241007718% przypadkow
# przeliczono 48.74399301004805% przypadkow
# przeliczono 48.74763361001893% przypadkow
# przeliczono 48.75127420998981% przypadkow
# przeliczono 48.75491480996068% przypadkow
# przeliczono 48.75855540993156% przypadkow
# przeliczono 48.76219600990243% przypadkow
# przeliczono 48.76583660987331% przypadkow
# przeliczono 48.76947720984418% przypadkow
# przeliczono 48.77311780981506% przypadkow
# przeliczono 48.776758409785934% przypadkow
# przeliczono 48.780399009756806% przypadkow
# przeliczono 48.78403960972768% przypadkow
# przeliczono 48.78768020969856% przypadkow
# przeliczono 48.791320809669436% przypadkow
# przeliczono 48.79496140964031% przypadkow
# przeliczono 48.79860200961119% przypadkow
# przeliczono 48.80224260958206% przypadkow
# przeliczono 48.80588320955294% przypadkow
# przeliczono 48.80952380952381% przypadkow
# przeliczono 48.81316440949469% przypadkow
# przeliczono 48.81680500946556% przypadkow
# przeliczono 48.82044560943643% przypadkow
# przeliczono 48.824086209407305% przypadkow
# przeliczono 48.827726809378184% przypadkow
# przeliczono 48.831367409349056% przypadkow
# przeliczono 48.835008009319935% przypadkow
# przeliczono 48.838648609290814% przypadkow
# przeliczono 48.842289209261686% przypadkow
# przeliczono 48.845929809232565% przypadkow
# przeliczono 48.84957040920344% przypadkow
# przeliczono 48.853211009174316% przypadkow
# przeliczono 48.85685160914519% przypadkow
# przeliczono 48.86049220911606% przypadkow
# przeliczono 48.86413280908693% przypadkow
# przeliczono 48.86777340905781% przypadkow
# przeliczono 48.87141400902868% przypadkow
# przeliczono 48.87505460899956% przypadkow
# przeliczono 48.87869520897044% przypadkow
# przeliczono 48.88233580894131% przypadkow
# przeliczono 48.88597640891219% przypadkow
# przeliczono 48.889617008883064% przypadkow
# przeliczono 48.89325760885394% przypadkow
# przeliczono 48.896898208824815% przypadkow
# przeliczono 48.90053880879569% przypadkow
# przeliczono 48.90417940876656% przypadkow
# przeliczono 48.90782000873744% przypadkow
# przeliczono 48.91146060870831% przypadkow
# przeliczono 48.91510120867919% przypadkow
# przeliczono 48.91874180865007% przypadkow
# przeliczono 48.92238240862094% przypadkow
# przeliczono 48.92602300859182% przypadkow
# przeliczono 48.92966360856269% przypadkow
# przeliczono 48.93330420853357% przypadkow
# przeliczono 48.93694480850444% przypadkow
# przeliczono 48.940585408475314% przypadkow
# przeliczono 48.94422600844619% przypadkow
# przeliczono 48.947866608417065% przypadkow
# przeliczono 48.95150720838794% przypadkow
# przeliczono 48.95514780835882% przypadkow
# przeliczono 48.958788408329696% przypadkow
# przeliczono 48.96242900830057% przypadkow
# przeliczono 48.96606960827145% przypadkow
# przeliczono 48.96971020824232% przypadkow
# przeliczono 48.9733508082132% przypadkow
# przeliczono 48.97699140818407% przypadkow
# przeliczono 48.98063200815494% przypadkow
# przeliczono 48.98427260812582% przypadkow
# przeliczono 48.98791320809669% przypadkow
# przeliczono 48.991553808067565% przypadkow
# przeliczono 48.995194408038444% przypadkow
# przeliczono 48.99883500800932% przypadkow
# przeliczono 49.002475607980195% przypadkow
# przeliczono 49.006116207951074% przypadkow
# przeliczono 49.009756807921946% przypadkow
# przeliczono 49.013397407892825% przypadkow
# przeliczono 49.0170380078637% przypadkow
# przeliczono 49.020678607834576% przypadkow
# przeliczono 49.02431920780545% przypadkow
# przeliczono 49.02795980777632% przypadkow
# przeliczono 49.03160040774719% przypadkow
# przeliczono 49.03524100771807% przypadkow
# przeliczono 49.03888160768894% przypadkow
# przeliczono 49.04252220765982% przypadkow
# przeliczono 49.0461628076307% przypadkow
# przeliczono 49.04980340760157% przypadkow
# przeliczono 49.05344400757245% przypadkow
# przeliczono 49.057084607543324% przypadkow
# przeliczono 49.0607252075142% przypadkow
# przeliczono 49.064365807485075% przypadkow
# przeliczono 49.06800640745595% przypadkow
# przeliczono 49.07164700742682% przypadkow
# przeliczono 49.0752876073977% przypadkow
# przeliczono 49.07892820736857% przypadkow
# przeliczono 49.08256880733945% przypadkow
# przeliczono 49.08620940731033% przypadkow
# przeliczono 49.0898500072812% przypadkow
# przeliczono 49.09349060725208% przypadkow
# przeliczono 49.09713120722295% przypadkow
# przeliczono 49.10077180719383% przypadkow
# przeliczono 49.1044124071647% przypadkow
# przeliczono 49.108053007135574% przypadkow
# przeliczono 49.111693607106446% przypadkow
# przeliczono 49.115334207077325% przypadkow
# przeliczono 49.1189748070482% przypadkow
# przeliczono 49.122615407019076% przypadkow
# przeliczono 49.126256006989955% przypadkow
# przeliczono 49.12989660696083% przypadkow
# przeliczono 49.133537206931706% przypadkow
# przeliczono 49.13717780690258% przypadkow
# przeliczono 49.14081840687346% przypadkow
# przeliczono 49.14445900684433% przypadkow
# przeliczono 49.1480996068152% przypadkow
# przeliczono 49.15174020678607% przypadkow
# przeliczono 49.15538080675695% przypadkow
# przeliczono 49.159021406727824% przypadkow
# przeliczono 49.1626620066987% przypadkow
# przeliczono 49.16630260666958% przypadkow
# przeliczono 49.169943206640454% przypadkow
# przeliczono 49.17358380661133% przypadkow
# przeliczono 49.177224406582205% przypadkow
# przeliczono 49.180865006553084% przypadkow
# przeliczono 49.184505606523956% przypadkow
# przeliczono 49.188146206494835% przypadkow
# przeliczono 49.19178680646571% przypadkow
# przeliczono 49.19542740643658% przypadkow
# przeliczono 49.19906800640745% przypadkow
# przeliczono 49.20270860637833% przypadkow
# przeliczono 49.2063492063492% przypadkow
# przeliczono 49.20998980632008% przypadkow
# przeliczono 49.21363040629096% przypadkow
# przeliczono 49.21727100626183% przypadkow
# przeliczono 49.22091160623271% przypadkow
# przeliczono 49.22455220620358% przypadkow
# przeliczono 49.22819280617446% przypadkow
# przeliczono 49.231833406145334% przypadkow
# przeliczono 49.235474006116206% przypadkow
# przeliczono 49.23911460608708% przypadkow
# przeliczono 49.24275520605796% przypadkow
# przeliczono 49.24639580602883% przypadkow
# przeliczono 49.25003640599971% przypadkow
# przeliczono 49.25367700597059% przypadkow
# przeliczono 49.25731760594146% przypadkow
# przeliczono 49.26095820591234% przypadkow
# przeliczono 49.26459880588321% przypadkow
# przeliczono 49.26823940585409% przypadkow
# przeliczono 49.27188000582496% przypadkow
# przeliczono 49.27552060579583% przypadkow
# przeliczono 49.279161205766705% przypadkow
# przeliczono 49.282801805737584% przypadkow
# przeliczono 49.286442405708456% przypadkow
# przeliczono 49.290083005679335% przypadkow
# przeliczono 49.293723605650214% przypadkow
# przeliczono 49.297364205621086% przypadkow
# przeliczono 49.301004805591965% przypadkow
# przeliczono 49.30464540556284% przypadkow
# przeliczono 49.308286005533716% przypadkow
# przeliczono 49.31192660550459% przypadkow
# przeliczono 49.31556720547546% przypadkow
# przeliczono 49.31920780544633% przypadkow
# przeliczono 49.32284840541721% przypadkow
# przeliczono 49.32648900538808% przypadkow
# przeliczono 49.33012960535896% przypadkow
# przeliczono 49.33377020532984% przypadkow
# przeliczono 49.33741080530071% przypadkow
# przeliczono 49.34105140527159% przypadkow
# przeliczono 49.344692005242464% przypadkow
# przeliczono 49.34833260521334% przypadkow
# przeliczono 49.351973205184215% przypadkow
# przeliczono 49.35561380515509% przypadkow
# przeliczono 49.35925440512597% przypadkow
# przeliczono 49.36289500509684% przypadkow
# przeliczono 49.36653560506771% przypadkow
# przeliczono 49.37017620503859% przypadkow
# przeliczono 49.37381680500946% przypadkow
# przeliczono 49.37745740498034% przypadkow
# przeliczono 49.38109800495122% przypadkow
# przeliczono 49.38473860492209% przypadkow
# przeliczono 49.38837920489297% przypadkow
# przeliczono 49.39201980486384% przypadkow
# przeliczono 49.395660404834715% przypadkow
# przeliczono 49.399301004805594% przypadkow
# przeliczono 49.402941604776466% przypadkow
# przeliczono 49.40658220474734% przypadkow
# przeliczono 49.41022280471822% przypadkow
# przeliczono 49.41386340468909% przypadkow
# przeliczono 49.41750400465997% przypadkow
# przeliczono 49.42114460463085% przypadkow
# przeliczono 49.42478520460172% przypadkow
# przeliczono 49.4284258045726% przypadkow
# przeliczono 49.43206640454347% przypadkow
# przeliczono 49.43570700451435% przypadkow
# przeliczono 49.43934760448522% przypadkow
# przeliczono 49.44298820445609% przypadkow
# przeliczono 49.446628804426965% przypadkow
# przeliczono 49.450269404397844% przypadkow
# przeliczono 49.453910004368716% przypadkow
# przeliczono 49.457550604339595% przypadkow
# przeliczono 49.461191204310474% przypadkow
# przeliczono 49.464831804281346% przypadkow
# przeliczono 49.468472404252225% przypadkow
# przeliczono 49.4721130042231% przypadkow
# przeliczono 49.475753604193976% przypadkow
# przeliczono 49.47939420416485% przypadkow
# przeliczono 49.48303480413572% przypadkow
# przeliczono 49.48667540410659% przypadkow
# przeliczono 49.49031600407747% przypadkow
# przeliczono 49.49395660404834% przypadkow
# przeliczono 49.49759720401922% przypadkow
# przeliczono 49.5012378039901% przypadkow
# przeliczono 49.50487840396097% przypadkow
# przeliczono 49.50851900393185% przypadkow
# przeliczono 49.512159603902724% przypadkow
# przeliczono 49.5158002038736% przypadkow
# przeliczono 49.519440803844475% przypadkow
# przeliczono 49.52308140381535% przypadkow
# przeliczono 49.52672200378622% przypadkow
# przeliczono 49.5303626037571% przypadkow
# przeliczono 49.53400320372797% przypadkow
# przeliczono 49.53764380369885% przypadkow
# przeliczono 49.54128440366973% przypadkow
# przeliczono 49.5449250036406% przypadkow
# przeliczono 49.54856560361148% przypadkow
# przeliczono 49.55220620358235% przypadkow
# przeliczono 49.55584680355323% przypadkow
# przeliczono 49.5594874035241% przypadkow
# przeliczono 49.563128003494974% przypadkow
# przeliczono 49.566768603465846% przypadkow
# przeliczono 49.570409203436725% przypadkow
# przeliczono 49.5740498034076% przypadkow
# przeliczono 49.577690403378476% przypadkow
# przeliczono 49.58133100334935% przypadkow
# przeliczono 49.58497160332023% przypadkow
# przeliczono 49.588612203291106% przypadkow
# przeliczono 49.59225280326198% przypadkow
# przeliczono 49.59589340323286% przypadkow
# przeliczono 49.59953400320373% przypadkow
# przeliczono 49.60317460317461% przypadkow
# przeliczono 49.60681520314548% przypadkow
# przeliczono 49.61045580311635% przypadkow
# przeliczono 49.614096403087224% przypadkow
# przeliczono 49.6177370030581% przypadkow
# przeliczono 49.621377603028975% przypadkow
# przeliczono 49.625018202999854% przypadkow
# przeliczono 49.62865880297073% przypadkow
# przeliczono 49.632299402941605% przypadkow
# przeliczono 49.635940002912484% przypadkow
# przeliczono 49.639580602883356% przypadkow
# przeliczono 49.643221202854235% przypadkow
# przeliczono 49.64686180282511% przypadkow
# przeliczono 49.65050240279598% przypadkow
# przeliczono 49.65414300276685% przypadkow
# przeliczono 49.65778360273773% przypadkow
# przeliczono 49.6614242027086% przypadkow
# przeliczono 49.66506480267948% przypadkow
# przeliczono 49.66870540265036% przypadkow
# przeliczono 49.67234600262123% przypadkow
# przeliczono 49.67598660259211% przypadkow
# przeliczono 49.67962720256298% przypadkow
# przeliczono 49.68326780253386% przypadkow
# przeliczono 49.686908402504734% przypadkow
# przeliczono 49.690549002475606% przypadkow
# przeliczono 49.69418960244648% przypadkow
# przeliczono 49.69783020241736% przypadkow
# przeliczono 49.70147080238823% przypadkow
# przeliczono 49.70511140235911% przypadkow
# przeliczono 49.70875200232999% przypadkow
# przeliczono 49.71239260230086% przypadkow
# przeliczono 49.71603320227174% przypadkow
# przeliczono 49.71967380224261% przypadkow
# przeliczono 49.72331440221349% przypadkow
# przeliczono 49.72695500218436% przypadkow
# przeliczono 49.73059560215523% przypadkow
# przeliczono 49.734236202126105% przypadkow
# przeliczono 49.737876802096984% przypadkow
# przeliczono 49.741517402067856% przypadkow
# przeliczono 49.745158002038735% przypadkow
# przeliczono 49.74879860200961% przypadkow
# przeliczono 49.752439201980486% przypadkow
# przeliczono 49.756079801951365% przypadkow
# przeliczono 49.75972040192224% przypadkow
# przeliczono 49.76336100189312% przypadkow
# przeliczono 49.76700160186399% przypadkow
# przeliczono 49.77064220183486% przypadkow
# przeliczono 49.77428280180574% przypadkow
# przeliczono 49.77792340177661% przypadkow
# przeliczono 49.78156400174748% przypadkow
# przeliczono 49.78520460171836% przypadkow
# przeliczono 49.788845201689234% przypadkow
# przeliczono 49.79248580166011% przypadkow
# przeliczono 49.79612640163099% przypadkow
# przeliczono 49.799767001601865% przypadkow
# przeliczono 49.803407601572744% przypadkow
# przeliczono 49.807048201543616% przypadkow
# przeliczono 49.81068880151449% przypadkow
# przeliczono 49.81432940148537% przypadkow
# przeliczono 49.81797000145624% przypadkow
# przeliczono 49.82161060142711% przypadkow
# przeliczono 49.82525120139799% przypadkow
# przeliczono 49.82889180136886% przypadkow
# przeliczono 49.83253240133974% przypadkow
# przeliczono 49.83617300131062% przypadkow
# przeliczono 49.83981360128149% przypadkow
# przeliczono 49.84345420125237% przypadkow
# przeliczono 49.84709480122324% przypadkow
# przeliczono 49.85073540119412% przypadkow
# przeliczono 49.854376001164994% przypadkow
# przeliczono 49.858016601135866% przypadkow
# przeliczono 49.86165720110674% przypadkow
# przeliczono 49.86529780107762% przypadkow
# przeliczono 49.86893840104849% przypadkow
# przeliczono 49.87257900101937% przypadkow
# przeliczono 49.87621960099025% przypadkow
# przeliczono 49.87986020096112% przypadkow
# przeliczono 49.883500800932% przypadkow
# przeliczono 49.88714140090287% przypadkow
# przeliczono 49.89078200087375% przypadkow
# przeliczono 49.89442260084462% przypadkow
# przeliczono 49.89806320081549% przypadkow
# przeliczono 49.901703800786365% przypadkow
# przeliczono 49.905344400757244% przypadkow
# przeliczono 49.908985000728116% przypadkow
# przeliczono 49.912625600698995% przypadkow
# przeliczono 49.91626620066987% przypadkow
# przeliczono 49.919906800640746% przypadkow
# przeliczono 49.923547400611625% przypadkow
# przeliczono 49.9271880005825% przypadkow
# przeliczono 49.930828600553376% przypadkow
# przeliczono 49.93446920052425% przypadkow
# przeliczono 49.93810980049512% przypadkow
# przeliczono 49.94175040046599% przypadkow
# przeliczono 49.94539100043687% przypadkow
# przeliczono 49.94903160040774% przypadkow
# przeliczono 49.95267220037862% przypadkow
# przeliczono 49.956312800349494% przypadkow
# przeliczono 49.95995340032037% przypadkow
# przeliczono 49.96359400029125% przypadkow
# przeliczono 49.967234600262124% przypadkow
# przeliczono 49.970875200233% przypadkow
# przeliczono 49.974515800203875% przypadkow
# przeliczono 49.97815640017475% przypadkow
# przeliczono 49.98179700014562% przypadkow
# przeliczono 49.9854376001165% przypadkow
# przeliczono 49.98907820008737% przypadkow
# przeliczono 49.99271880005825% przypadkow
# przeliczono 49.99635940002912% przypadkow
# przeliczono 50.0% przypadkow
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27468 entries, 0 to 649713
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   27468 non-null  int64
#  1   STATUS               27468 non-null  int32
#  2   CODE_GENDER          27468 non-null  object
#  3   FLAG_OWN_CAR         27468 non-null  object
#  4   FLAG_OWN_REALTY      27468 non-null  object
#  5   CNT_CHILDREN         27468 non-null  int64
#  6   AMT_INCOME_TOTAL     27468 non-null  float64
#  7   NAME_INCOME_TYPE     27468 non-null  object
#  8   NAME_EDUCATION_TYPE  27468 non-null  object
#  9   NAME_FAMILY_STATUS   27468 non-null  object
#  10  NAME_HOUSING_TYPE    27468 non-null  object
#  11  DAYS_BIRTH           27468 non-null  int64
#  12  DAYS_EMPLOYED        27468 non-null  int64
#  13  FLAG_MOBIL           27468 non-null  int64
#  14  FLAG_WORK_PHONE      27468 non-null  int64
#  15  FLAG_PHONE           27468 non-null  int64
#  16  FLAG_EMAIL           27468 non-null  int64
#  17  OCCUPATION_TYPE      22737 non-null  object
#  18  CNT_FAM_MEMBERS      27468 non-null  float64
# dtypes: float64(2), int32(1), int64(8), object(8)
# memory usage: 4.1+ MB

# %%
df1.reset_index(drop=True)
# Out:
#             ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804       0           M            Y               Y             0
# 1      5008805       0           M            Y               Y             0
# 2      5008806       0           M            Y               Y             0
# 3      5008808       0           F            N               Y             0
# 4      5008810       0           F            N               Y             0
# ...        ...     ...         ...          ...             ...           ...
# 27463  5150480       0           F            Y               Y             1
# 27464  5150482       0           F            Y               Y             1
# 27465  5150484       0           F            Y               Y             1
# 27466  5150485       0           F            Y               Y             1
# 27467  5150487       0           M            Y               N             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0             427500.00               Working               Higher education
# 1             427500.00               Working               Higher education
# 2             112500.00               Working  Secondary / secondary special
# 3             270000.00  Commercial associate  Secondary / secondary special
# 4             270000.00  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 27463         157500.00               Working  Secondary / secondary special
# 27464         157500.00               Working  Secondary / secondary special
# 27465         157500.00               Working  Secondary / secondary special
# 27466         157500.00               Working  Secondary / secondary special
# 27467         202500.00               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment      -12005          -4542
# 1            Civil marriage   Rented apartment      -12005          -4542
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 27463               Married  House / apartment      -10808          -1739
# 27464               Married  House / apartment      -10808          -1739
# 27465               Married  House / apartment      -10808          -1739
# 27466               Married  House / apartment      -10808          -1739
# 27467               Married  House / apartment      -19398          -2166
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 27463           1                0           0           0      Core staff
# 27464           1                0           0           0      Core staff
# 27465           1                0           0           0      Core staff
# 27466           1                0           0           0      Core staff
# 27467           1                0           0           0         Drivers
#
#        CNT_FAM_MEMBERS
# 0                 2.00
# 1                 2.00
# 2                 2.00
# 3                 1.00
# 4                 1.00
# ...                ...
# 27463             3.00
# 27464             3.00
# 27465             3.00
# 27466             3.00
# 27467             2.00
#
# [27468 rows x 19 columns]

# %%
# M - 1 # Y - 1
# F - 0 # N - 0
# Standaryzacja kolumn CODE_GENDER, FLAG_OWN_REALITY oraz FLAG_OWN_CAR (zamiana M - 1, F - 0, Y - 1, N - 0 itp.)

df1.loc[df['CODE_GENDER'].isin(['M']),'CODE_GENDER'] = '1'
df1.loc[df['CODE_GENDER'].isin(['F']),'CODE_GENDER'] = '0'

df1.loc[df['FLAG_OWN_REALTY'].isin(['Y']),'FLAG_OWN_REALTY'] = '1'
df1.loc[df['FLAG_OWN_REALTY'].isin(['N']),'FLAG_OWN_REALTY'] = '0'

df1.loc[df['FLAG_OWN_CAR'].isin(['Y']),'FLAG_OWN_CAR'] = '1'
df1.loc[df['FLAG_OWN_CAR'].isin(['N']),'FLAG_OWN_CAR'] = '0'

# %%
# wyliczenie wieku klienta oraz ilość lat zatrudnienia, zostały dodane nowej kolumny na końcu

df1['Day_Birth'] = df1['DAYS_BIRTH'].abs()/365
df1['Day_Birth'] = df1['Day_Birth'].astype('int64')

df1['Day_Emplyed'] = df1['DAYS_EMPLOYED'].abs()/365
df1['Day_Emplyed'] = df1['Day_Emplyed'].astype('int64')

# %%
df1.head(4)
# Out:
#          ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0   5008804       0           1            1               1             0
# 16  5008805       0           1            1               1             0
# 31  5008806       0           1            1               1             0
# 61  5008808       0           0            0               1             0
#
#     AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.00               Working               Higher education
# 16         427500.00               Working               Higher education
# 31         112500.00               Working  Secondary / secondary special
# 61         270000.00  Commercial associate  Secondary / secondary special
#
#       NAME_FAMILY_STATUS  ... DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0         Civil marriage  ...     -12005          -4542           1
# 16        Civil marriage  ...     -12005          -4542           1
# 31               Married  ...     -21474          -1134           1
# 61  Single / not married  ...     -19110          -3051           1
#
#     FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE CNT_FAM_MEMBERS  \
# 0                 1           0           0              NaN            2.00
# 16                1           0           0              NaN            2.00
# 31                0           0           0   Security staff            2.00
# 61                0           1           1      Sales staff            1.00
#
#     Day_Birth  Day_Emplyed
# 0          32           12
# 16         32           12
# 31         58            3
# 61         52            8
#
# [4 rows x 21 columns]

# %%
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# NAME_HOUSING_TYPE
# NAME_FAMILY_STATUS

# sprawdzenie ilości wystąpień dla poszczególnych kolumn (tam gdzie wystąpuje dtype==text). 
# wszystko po to żeby można było zrobić standaryzacje i normalizację. (0 ,1) 
# dla NAME_EDUCATION_STATUS można zrobić kategoryzację wg określonego stopnia edukacji, gdyż będzie to miało
# wpływ na nasz model, jeśli ktoś ma lepsze wykształcenie (np. Lower - 0, Secondar - 1 etc.)
# dla pozostałych kolumn należy zrobić standaryzację i normalizację 0 i 1.

df1["NAME_EDUCATION_TYPE"].value_counts()
# Out:
# Secondary / secondary special    18043
# Higher education                  7965
# Incomplete higher                 1234
# Lower secondary                    198
# Academic degree                     28
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %% [markdown]
# ## Anna

# %%
#Przypisanie skali punktowej  do typu edukacji 
df1.loc[df['NAME_EDUCATION_TYPE'].isin(['Secondary / secondary special']),'NAME_EDUCATION_TYPE'] = '1'
df1.loc[df['NAME_EDUCATION_TYPE'].isin(['Higher education']),'NAME_EDUCATION_TYPE'] = '3'
df1.loc[df['NAME_EDUCATION_TYPE'].isin(['Incomplete higher']),'NAME_EDUCATION_TYPE'] = '2'
df1.loc[df['NAME_EDUCATION_TYPE'].isin(['Lower secondary']),'NAME_EDUCATION_TYPE'] = '0'
df1.loc[df['NAME_EDUCATION_TYPE'].isin(['Academic degree']),'NAME_EDUCATION_TYPE'] = '4'

# %%
#Przypisanie skali punktowej  do typu dochodów, dzielimy na umowę o pracę (2), działalność (1) i inne  (0)
df1.loc[df['NAME_INCOME_TYPE'].isin(['Working']),'NAME_INCOME_TYPE'] = '2'
df1.loc[df['NAME_INCOME_TYPE'].isin(['Commercial associate']),'NAME_INCOME_TYPE'] = '1'
df1.loc[df['NAME_INCOME_TYPE'].isin(['State servant', 'Pensioner', 'Student']),'NAME_INCOME_TYPE'] = '0'

# %%
#Przypisanie skali punktowej - singiel (1) lub nie (0)
df1.loc[df['NAME_FAMILY_STATUS'].isin(['Married', 'Civil marriage']),'NAME_FAMILY_STATUS'] = '1'
df1.loc[df['NAME_FAMILY_STATUS'].isin(['Widow', 'Separated', 'Single / not married']),'NAME_FAMILY_STATUS'] = '0'

# %%
#Przypisanie skali punktowej - dom lub mieszkanie(1) lub inne (0)
df1.loc[df['NAME_HOUSING_TYPE'].isin(['House / apartment']),'NAME_HOUSING_TYPE'] = '1'
df1.loc[df['NAME_HOUSING_TYPE'].isin(['With parents', 'Municipal apartment', 
                                      'Rented apartment', 'Office apartment', 'Co-op apartment' ]),'NAME_HOUSING_TYPE'] = '0'

# %%
#Podział dochodów na przedziały i przypisanie kategorii (z użyciem cat codes)
bins = pd.IntervalIndex.from_tuples([(0, 150000), (150000, 185000), (185000, 200000), (200000, 225000), (225000, 10000000)])
df["INCOME"] = pd.cut(df["AMT_INCOME_TOTAL"], bins)
bin_grouped_all = df.groupby(by= "INCOME" ).count()
df1["INCOME"]=df["INCOME"].cat.codes;

# %%
#Podział wieku  na przedziały 
bins = pd.IntervalIndex.from_tuples([(0, 30), (30, 40), (40, 50), (50, 60), (60, 100)])
df1["AGE"] = pd.cut(df1["Day_Birth"], bins)
bin_grouped_all = df1.groupby(by= "AGE" ).count()
df1["AGE"]=df1["AGE"].cat.codes;

# %%
df1.reset_index(drop=True)
# Out:
#             ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804       0           1            1               1             0
# 1      5008805       0           1            1               1             0
# 2      5008806       0           1            1               1             0
# 3      5008808       0           0            0               1             0
# 4      5008810       0           0            0               1             0
# ...        ...     ...         ...          ...             ...           ...
# 27463  5150480       0           0            1               1             1
# 27464  5150482       0           0            1               1             1
# 27465  5150484       0           0            1               1             1
# 27466  5150485       0           0            1               1             1
# 27467  5150487       0           1            1               0             0
#
#        AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 0             427500.00                2                   3
# 1             427500.00                2                   3
# 2             112500.00                2                   1
# 3             270000.00                1                   1
# 4             270000.00                1                   1
# ...                 ...              ...                 ...
# 27463         157500.00                2                   1
# 27464         157500.00                2                   1
# 27465         157500.00                2                   1
# 27466         157500.00                2                   1
# 27467         202500.00                2                   1
#
#       NAME_FAMILY_STATUS  ... FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0                      1  ...          1                1           0
# 1                      1  ...          1                1           0
# 2                      1  ...          1                0           0
# 3                      0  ...          1                0           1
# 4                      0  ...          1                0           1
# ...                  ...  ...        ...              ...         ...
# 27463                  1  ...          1                0           0
# 27464                  1  ...          1                0           0
# 27465                  1  ...          1                0           0
# 27466                  1  ...          1                0           0
# 27467                  1  ...          1                0           0
#
#        FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  Day_Birth Day_Emplyed  \
# 0               0              NaN             2.00         32          12
# 1               0              NaN             2.00         32          12
# 2               0   Security staff             2.00         58           3
# 3               1      Sales staff             1.00         52           8
# 4               1      Sales staff             1.00         52           8
# ...           ...              ...              ...        ...         ...
# 27463           0       Core staff             3.00         29           4
# 27464           0       Core staff             3.00         29           4
# 27465           0       Core staff             3.00         29           4
# 27466           0       Core staff             3.00         29           4
# 27467           0          Drivers             2.00         53           5
#
#        INCOME  AGE
# 0           4    1
# 1           4    1
# 2           0    3
# 3           4    3
# 4           4    3
# ...       ...  ...
# 27463       1    0
# 27464       1    0
# 27465       1    0
# 27466       1    0
# 27467       3    3
#
# [27468 rows x 23 columns]

# %% [markdown]
# # Dawid-dopracowanie danych

# %%
df1
# Out:
#              ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0       5008804       0           1            1               1
# 16      5008805       0           1            1               1
# 31      5008806       0           1            1               1
# 61      5008808       0           0            0               1
# 71      5008810       0           0            0               1
# ...         ...     ...         ...          ...             ...
# 649593  5150480       0           0            1               1
# 649662  5150482       0           0            1               1
# 649698  5150484       0           0            1               1
# 649711  5150485       0           0            1               1
# 649713  5150487       0           1            1               0
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 0                  0         427500.00                2                   3
# 16                 0         427500.00                2                   3
# 31                 0         112500.00                2                   1
# 61                 0         270000.00                1                   1
# 71                 0         270000.00                1                   1
# ...              ...               ...              ...                 ...
# 649593             1         157500.00                2                   1
# 649662             1         157500.00                2                   1
# 649698             1         157500.00                2                   1
# 649711             1         157500.00                2                   1
# 649713             0         202500.00                2                   1
#
#        NAME_FAMILY_STATUS  ... FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0                       1  ...          1                1           0
# 16                      1  ...          1                1           0
# 31                      1  ...          1                0           0
# 61                      0  ...          1                0           1
# 71                      0  ...          1                0           1
# ...                   ...  ...        ...              ...         ...
# 649593                  1  ...          1                0           0
# 649662                  1  ...          1                0           0
# 649698                  1  ...          1                0           0
# 649711                  1  ...          1                0           0
# 649713                  1  ...          1                0           0
#
#         FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  Day_Birth Day_Emplyed  \
# 0                0              NaN             2.00         32          12
# 16               0              NaN             2.00         32          12
# 31               0   Security staff             2.00         58           3
# 61               1      Sales staff             1.00         52           8
# 71               1      Sales staff             1.00         52           8
# ...            ...              ...              ...        ...         ...
# 649593           0       Core staff             3.00         29           4
# 649662           0       Core staff             3.00         29           4
# 649698           0       Core staff             3.00         29           4
# 649711           0       Core staff             3.00         29           4
# 649713           0          Drivers             2.00         53           5
#
#         INCOME  AGE
# 0            4    1
# 16           4    1
# 31           0    3
# 61           4    3
# 71           4    3
# ...        ...  ...
# 649593       1    0
# 649662       1    0
# 649698       1    0
# 649711       1    0
# 649713       3    3
#
# [27468 rows x 23 columns]

# %%
#df1[['AGE','SENIORITY']] = df1[['Day_Birth', 'Day_Emplyed']]

# %%
df1 = df1.drop(columns=['Day_Birth','Day_Emplyed'])
df1
# Out:
#              ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0       5008804       0           1            1               1
# 16      5008805       0           1            1               1
# 31      5008806       0           1            1               1
# 61      5008808       0           0            0               1
# 71      5008810       0           0            0               1
# ...         ...     ...         ...          ...             ...
# 649593  5150480       0           0            1               1
# 649662  5150482       0           0            1               1
# 649698  5150484       0           0            1               1
# 649711  5150485       0           0            1               1
# 649713  5150487       0           1            1               0
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 0                  0         427500.00                2                   3
# 16                 0         427500.00                2                   3
# 31                 0         112500.00                2                   1
# 61                 0         270000.00                1                   1
# 71                 0         270000.00                1                   1
# ...              ...               ...              ...                 ...
# 649593             1         157500.00                2                   1
# 649662             1         157500.00                2                   1
# 649698             1         157500.00                2                   1
# 649711             1         157500.00                2                   1
# 649713             0         202500.00                2                   1
#
#        NAME_FAMILY_STATUS  ... DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0                       1  ...     -12005          -4542           1
# 16                      1  ...     -12005          -4542           1
# 31                      1  ...     -21474          -1134           1
# 61                      0  ...     -19110          -3051           1
# 71                      0  ...     -19110          -3051           1
# ...                   ...  ...        ...            ...         ...
# 649593                  1  ...     -10808          -1739           1
# 649662                  1  ...     -10808          -1739           1
# 649698                  1  ...     -10808          -1739           1
# 649711                  1  ...     -10808          -1739           1
# 649713                  1  ...     -19398          -2166           1
#
#         FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 0                     1           0           0              NaN
# 16                    1           0           0              NaN
# 31                    0           0           0   Security staff
# 61                    0           1           1      Sales staff
# 71                    0           1           1      Sales staff
# ...                 ...         ...         ...              ...
# 649593                0           0           0       Core staff
# 649662                0           0           0       Core staff
# 649698                0           0           0       Core staff
# 649711                0           0           0       Core staff
# 649713                0           0           0          Drivers
#
#        CNT_FAM_MEMBERS  INCOME  AGE
# 0                 2.00       4    1
# 16                2.00       4    1
# 31                2.00       0    3
# 61                1.00       4    3
# 71                1.00       4    3
# ...                ...     ...  ...
# 649593            3.00       1    0
# 649662            3.00       1    0
# 649698            3.00       1    0
# 649711            3.00       1    0
# 649713            2.00       3    3
#
# [27468 rows x 21 columns]

# %%
df1['CNT_FAM_MEMBERS'] = df1['CNT_FAM_MEMBERS'].astype('int64')

# %%
df1
# Out:
#              ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0       5008804       0           1            1               1
# 16      5008805       0           1            1               1
# 31      5008806       0           1            1               1
# 61      5008808       0           0            0               1
# 71      5008810       0           0            0               1
# ...         ...     ...         ...          ...             ...
# 649593  5150480       0           0            1               1
# 649662  5150482       0           0            1               1
# 649698  5150484       0           0            1               1
# 649711  5150485       0           0            1               1
# 649713  5150487       0           1            1               0
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 0                  0         427500.00                2                   3
# 16                 0         427500.00                2                   3
# 31                 0         112500.00                2                   1
# 61                 0         270000.00                1                   1
# 71                 0         270000.00                1                   1
# ...              ...               ...              ...                 ...
# 649593             1         157500.00                2                   1
# 649662             1         157500.00                2                   1
# 649698             1         157500.00                2                   1
# 649711             1         157500.00                2                   1
# 649713             0         202500.00                2                   1
#
#        NAME_FAMILY_STATUS  ... DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0                       1  ...     -12005          -4542           1
# 16                      1  ...     -12005          -4542           1
# 31                      1  ...     -21474          -1134           1
# 61                      0  ...     -19110          -3051           1
# 71                      0  ...     -19110          -3051           1
# ...                   ...  ...        ...            ...         ...
# 649593                  1  ...     -10808          -1739           1
# 649662                  1  ...     -10808          -1739           1
# 649698                  1  ...     -10808          -1739           1
# 649711                  1  ...     -10808          -1739           1
# 649713                  1  ...     -19398          -2166           1
#
#         FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 0                     1           0           0              NaN
# 16                    1           0           0              NaN
# 31                    0           0           0   Security staff
# 61                    0           1           1      Sales staff
# 71                    0           1           1      Sales staff
# ...                 ...         ...         ...              ...
# 649593                0           0           0       Core staff
# 649662                0           0           0       Core staff
# 649698                0           0           0       Core staff
# 649711                0           0           0       Core staff
# 649713                0           0           0          Drivers
#
#        CNT_FAM_MEMBERS  INCOME  AGE
# 0                    2       4    1
# 16                   2       4    1
# 31                   2       0    3
# 61                   1       4    3
# 71                   1       4    3
# ...                ...     ...  ...
# 649593               3       1    0
# 649662               3       1    0
# 649698               3       1    0
# 649711               3       1    0
# 649713               2       3    3
#
# [27468 rows x 21 columns]

# %%
for i in df1.columns:
    print(i, sum(df1[i].isna()))
    
# ID 0
# CODE_GENDER 0
# FLAG_OWN_CAR 0
# FLAG_OWN_REALTY 0
# CNT_CHILDREN 0
# AMT_INCOME_TOTAL 0
# NAME_INCOME_TYPE 0
# NAME_EDUCATION_TYPE 0
# NAME_FAMILY_STATUS 0
# NAME_HOUSING_TYPE 0
# DAYS_BIRTH 0
# DAYS_EMPLOYED 0
# FLAG_MOBIL 0
# FLAG_WORK_PHONE 0
# FLAG_PHONE 0
# FLAG_EMAIL 0
# OCCUPATION_TYPE 91820
# CNT_FAM_MEMBERS 0
# INCOME 0
# AGE 0
# y 0
# SENIORITY 0
# Out:
# ID 0
# STATUS 0
# CODE_GENDER 0
# FLAG_OWN_CAR 0
# FLAG_OWN_REALTY 0
# CNT_CHILDREN 0
# AMT_INCOME_TOTAL 0
# NAME_INCOME_TYPE 0
# NAME_EDUCATION_TYPE 0
# NAME_FAMILY_STATUS 0
# NAME_HOUSING_TYPE 0
# DAYS_BIRTH 0
# DAYS_EMPLOYED 0
# FLAG_MOBIL 0
# FLAG_WORK_PHONE 0
# FLAG_PHONE 0
# FLAG_EMAIL 0
# OCCUPATION_TYPE 4731
# CNT_FAM_MEMBERS 0
# INCOME 0
# AGE 0

# %%
print(len(df1['OCCUPATION_TYPE']))
print(df1['OCCUPATION_TYPE'].value_counts())
print(len(df1['OCCUPATION_TYPE'])-sum(df1['OCCUPATION_TYPE'].isna()))
# Out:
# 27468
# Laborers                 5601
# Core staff               3250
# Sales staff              3156
# Managers                 2695
# Drivers                  1934
# High skill tech staff    1269
# Medicine staff           1124
# Accountants              1106
# Cooking staff             587
# Security staff            547
# Cleaning staff            511
# Private service staff     293
# Waiters/barmen staff      163
# Low-skill Laborers        159
# Secretaries               142
# HR staff                   76
# Realty agents              67
# IT staff                   57
# Name: OCCUPATION_TYPE, dtype: int64
# 22737

# %%
df_no_na = df1[df1['OCCUPATION_TYPE'].isna() == False]
df_no_na
# Out:
#              ID  STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 31      5008806       0           1            1               1
# 61      5008808       0           0            0               1
# 71      5008810       0           0            0               1
# 98      5008811       0           0            0               1
# 137     5008815       0           1            1               1
# ...         ...     ...         ...          ...             ...
# 649593  5150480       0           0            1               1
# 649662  5150482       0           0            1               1
# 649698  5150484       0           0            1               1
# 649711  5150485       0           0            1               1
# 649713  5150487       0           1            1               0
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 31                 0         112500.00                2                   1
# 61                 0         270000.00                1                   1
# 71                 0         270000.00                1                   1
# 98                 0         270000.00                1                   1
# 137                0         270000.00                2                   3
# ...              ...               ...              ...                 ...
# 649593             1         157500.00                2                   1
# 649662             1         157500.00                2                   1
# 649698             1         157500.00                2                   1
# 649711             1         157500.00                2                   1
# 649713             0         202500.00                2                   1
#
#        NAME_FAMILY_STATUS  ... DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 31                      1  ...     -21474          -1134           1
# 61                      0  ...     -19110          -3051           1
# 71                      0  ...     -19110          -3051           1
# 98                      0  ...     -19110          -3051           1
# 137                     1  ...     -16872           -769           1
# ...                   ...  ...        ...            ...         ...
# 649593                  1  ...     -10808          -1739           1
# 649662                  1  ...     -10808          -1739           1
# 649698                  1  ...     -10808          -1739           1
# 649711                  1  ...     -10808          -1739           1
# 649713                  1  ...     -19398          -2166           1
#
#         FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 31                    0           0           0   Security staff
# 61                    0           1           1      Sales staff
# 71                    0           1           1      Sales staff
# 98                    0           1           1      Sales staff
# 137                   1           1           1      Accountants
# ...                 ...         ...         ...              ...
# 649593                0           0           0       Core staff
# 649662                0           0           0       Core staff
# 649698                0           0           0       Core staff
# 649711                0           0           0       Core staff
# 649713                0           0           0          Drivers
#
#        CNT_FAM_MEMBERS  INCOME  AGE
# 31                   2       0    3
# 61                   1       4    3
# 71                   1       4    3
# 98                   1       4    3
# 137                  2       4    2
# ...                ...     ...  ...
# 649593               3       1    0
# 649662               3       1    0
# 649698               3       1    0
# 649711               3       1    0
# 649713               2       3    3
#
# [22737 rows x 21 columns]

# %% [markdown]
# # Ania - modele w oparciu o df Dawida

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
y =df_no_na['STATUS']
y
# Out:
# 31        0
# 61        0
# 71        0
# 98        0
# 137       0
#          ..
# 649593    0
# 649662    0
# 649698    0
# 649711    0
# 649713    0
# Name: STATUS, Length: 22737, dtype: int32

# %%
X = df_no_na.drop(columns=['ID','STATUS', 'OCCUPATION_TYPE', 'DAYS_EMPLOYED', 'DAYS_BIRTH', 'AMT_INCOME_TOTAL'])
X
# Out:
#        CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 31               1            1               1             0
# 61               0            0               1             0
# 71               0            0               1             0
# 98               0            0               1             0
# 137              1            1               1             0
# ...            ...          ...             ...           ...
# 649593           0            1               1             1
# 649662           0            1               1             1
# 649698           0            1               1             1
# 649711           0            1               1             1
# 649713           1            1               0             0
#
#        NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 31                    2                   1                  1
# 61                    1                   1                  0
# 71                    1                   1                  0
# 98                    1                   1                  0
# 137                   2                   3                  1
# ...                 ...                 ...                ...
# 649593                2                   1                  1
# 649662                2                   1                  1
# 649698                2                   1                  1
# 649711                2                   1                  1
# 649713                2                   1                  1
#
#        NAME_HOUSING_TYPE  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 31                     1           1                0           0           0
# 61                     1           1                0           1           1
# 71                     1           1                0           1           1
# 98                     1           1                0           1           1
# 137                    1           1                1           1           1
# ...                  ...         ...              ...         ...         ...
# 649593                 1           1                0           0           0
# 649662                 1           1                0           0           0
# 649698                 1           1                0           0           0
# 649711                 1           1                0           0           0
# 649713                 1           1                0           0           0
#
#         CNT_FAM_MEMBERS  INCOME  AGE
# 31                    2       0    3
# 61                    1       4    3
# 71                    1       4    3
# 98                    1       4    3
# 137                   2       4    2
# ...                 ...     ...  ...
# 649593                3       1    0
# 649662                3       1    0
# 649698                3       1    0
# 649711                3       1    0
# 649713                2       3    3
#
# [22737 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                   test_size=.2,
                                                   random_state=1)

# %%
st_scaler = StandardScaler()
X_train = st_scaler.fit_transform(X_train)
X_test = st_scaler.fit_transform(X_test)

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import KFold
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
rf = RandomForestClassifier(random_state = 1) 
rf.fit(X_train, y_train)

ac = accuracy_score(y_test,rf.predict(X_test))
print('Accuracy dla Random Forest wynosi: ',ac, '\n')
# Out:
# Accuracy dla Random Forest wynosi:  0.9824098504837291

# %%
from sklearn.feature_selection import RFECV

rf1 = RandomForestClassifier(random_state = 1) 
rfecv = RFECV(estimator=rf1, step=1, cv=k_fold,scoring='accuracy')   
rfecv = rfecv.fit(X_train, y_train)

print('Optymalna liczba cech do modelu :', rfecv.n_features_)
print('Wybrane cechy :', X.columns[rfecv.support_])  

#Analiza pokazała, że korzystne jest wybranie 9 cech
# Out:
# Optymalna liczba cech do modelu : 9
# Wybrane cechy : Index(['FLAG_OWN_CAR', 'CNT_CHILDREN', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'CNT_FAM_MEMBERS', 'INCOME', 'AGE'],
#       dtype='object')

# %%
X_1 = X[['FLAG_OWN_CAR', 'CNT_CHILDREN', 'NAME_INCOME_TYPE',
       'NAME_EDUCATION_TYPE', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
       'CNT_FAM_MEMBERS', 'INCOME', 'AGE']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_1,y, test_size=0.25, random_state=1)

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
rf_2 = RandomForestClassifier(random_state=42)      
rf_2 = rf_2.fit(X_train,y_train)

# %%
ac = accuracy_score(y_test, rf_2.predict(X_test))
print('Accuracy is: ',ac, '\n')
# Out:
# Accuracy is:  0.9824098504837291

# %% [markdown]
# Ale ostatecznie accurancy nie zmieniło się, więc zostajemy przy poprzednim wyborze.

# %%
y =df_no_na['STATUS']
X = df_no_na.drop(columns=['ID','STATUS', 'OCCUPATION_TYPE', 'DAYS_EMPLOYED', 'DAYS_BIRTH', 'AMT_INCOME_TOTAL'])
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2,random_state=1)
st_scaler = StandardScaler()
X_train = st_scaler.fit_transform(X_train)
X_test = st_scaler.fit_transform(X_test)                                                   

rf = RandomForestClassifier(random_state = 1) 
rf.fit(X_train, y_train)

ac = accuracy_score(y_test,rf.predict(X_test))
print('Accuracy dla Random Forest wynosi: ',ac, '\n')
# Out:
# Accuracy dla Random Forest wynosi:  0.9824098504837291

# %% [markdown]
# # Regresja logistyczna

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression() 
logreg.fit(X_train,y_train)

ac = accuracy_score(y_test,logreg.predict(X_test))
print('Accuracy dla Regresji Logistycznej wynosi: ',ac, '\n')
# Out:
# Accuracy dla Regresji Logistycznej wynosi:  0.9826297273526825

# %%
list = [100, 500, 1000, 5000, 10000]
acc_list=[]

for element in list:
    logreg = LogisticRegression(max_iter=int(element))
    logreg.fit(X_train,y_train)
    acc_score_it = logreg.score(X_train, y_train)
    acc_list.append(acc_score_it)
    

print(acc_list)
# Out:
# [0.9811424487327506, 0.9811424487327506, 0.9811424487327506, 0.9811424487327506, 0.9811424487327506]

# %% [markdown]
# Również zostajemy przy domyślnych ustawieniach.

# %% [markdown]
# # KNN

# %%
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.9815303430079155

# %%
neighbors = np.arange(0,25)
cv_scores = []

# %%
for k in neighbors:
    k_value = k+1
    knn = KNeighborsClassifier(n_neighbors = k_value, weights='uniform', p=2, metric='euclidean')
    kfold = model_selection.KFold(n_splits=10, random_state=123)
    scores = model_selection.cross_val_score(knn, X_train, y_train, cv=k_fold, scoring='accuracy')
    cv_scores.append(scores.mean()*100)
    print("k=%d %0.2f (+/- %0.2f)" % (k_value, scores.mean()*100, scores.std()*100))

optimal_k = neighbors[cv_scores.index(max(cv_scores))]
print ("Optymalna liczba sąsiadów to  %d z %0.1f%%" % (optimal_k, cv_scores[optimal_k]))
# Out:
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=1 97.20 (+/- 0.49)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=2 98.03 (+/- 0.32)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=3 97.81 (+/- 0.31)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=4 97.99 (+/- 0.29)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=5 97.94 (+/- 0.32)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=6 98.08 (+/- 0.28)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=7 98.08 (+/- 0.28)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=8 98.10 (+/- 0.28)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=9 98.09 (+/- 0.29)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=10 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=11 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=12 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=13 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=14 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=15 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=16 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=17 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=18 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=19 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=20 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=21 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=22 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=23 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=24 98.11 (+/- 0.27)
# C:\Users\OEM\anaconda3\envs\tf2\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# k=25 98.11 (+/- 0.27)
# Optymalna liczba sąsiadów to  9 z 98.1%

# %%
knn1 = KNeighborsClassifier(n_neighbors=9)
knn1.fit(X_train, y_train)

ac = accuracy_score(y_test,knn1.predict(X_test))
print('Accuracy dla KNN wynosi: ',ac, '\n')
# Out:
# Accuracy dla KNN wynosi:  0.9824098504837291

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
gaussiannb= GaussianNB()
gaussiannb.fit(X_train, y_train)
ac = accuracy_score(y_test,gaussiannb.predict(X_test))
print('Accuracy dla GaussianNB wynosi:: ',ac,'\n')
# Out:
# Accuracy dla GaussianNB wynosi::  0.9826297273526825

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(criterion='gini') #criterion = entopy, gini
dtree.fit(X_train, y_train)
ac = accuracy_score(y_test,dtree.predict(X_test))
print('Accuracy is: ',ac, '\n')
# Out:
# Accuracy is:  0.9815303430079155

# %%
fig, ax_arr = plt.subplots(nrows = 2, ncols = 3, figsize = (20,15))
from sklearn import metrics

#RandomForest
probs = rf.predict_proba(X_test)
preds = probs[:,1]
fprrfc, tprrfc, thresholdrfc = metrics.roc_curve(y_test, preds)
roc_aucrfc = metrics.auc(fprrfc, tprrfc)

ax_arr[0,0].plot(fprrfc, tprrfc, 'b', label = 'AUC = %0.2f' % roc_aucrfc)
ax_arr[0,0].plot([0, 1], [0, 1],'r--')
ax_arr[0,0].set_title('ROC Random Forest ',fontsize=20)
ax_arr[0,0].set_ylabel('True Positive Rate',fontsize=20)
ax_arr[0,0].set_xlabel('False Positive Rate',fontsize=15)
ax_arr[0,0].legend(loc = 'lower right', prop={'size': 16})

#LOGREG
probs = logreg.predict_proba(X_test)
preds = probs[:,1]
fprlog, tprlog, thresholdlog = metrics.roc_curve(y_test, preds)
roc_auclog = metrics.auc(fprlog, tprlog)

ax_arr[0,1].plot(fprlog, tprlog, 'b', label = 'AUC = %0.2f' % roc_auclog)
ax_arr[0,1].plot([0, 1], [0, 1],'r--')
ax_arr[0,1].set_title('ROC Logistic ',fontsize=20)
ax_arr[0,1].set_ylabel('True Positive Rate',fontsize=20)
ax_arr[0,1].set_xlabel('False Positive Rate',fontsize=15)
ax_arr[0,1].legend(loc = 'lower right', prop={'size': 16})

#KNN
probs = knn1.predict_proba(X_test)
preds = probs[:,1]
fprknn, tprknn, thresholdknn = metrics.roc_curve(y_test, preds)
roc_aucknn = metrics.auc(fprknn, tprknn)

ax_arr[0,2].plot(fprknn, tprknn, 'b', label = 'AUC = %0.2f' % roc_aucknn)
ax_arr[0,2].plot([0, 1], [0, 1],'r--')
ax_arr[0,2].set_title('ROC KNN ',fontsize=20)
ax_arr[0,2].set_ylabel('True Positive Rate',fontsize=20)
ax_arr[0,2].set_xlabel('False Positive Rate',fontsize=15)
ax_arr[0,2].legend(loc = 'lower right', prop={'size': 16})

#Gaussian NB
probs = gaussiannb.predict_proba(X_test)
preds = probs[:,1]
fprgau, tprgau, thresholdgau = metrics.roc_curve(y_test, preds)
roc_aucgau = metrics.auc(fprgau, tprgau)

ax_arr[1,1].plot(fprgau, tprgau, 'b', label = 'AUC = %0.2f' % roc_aucgau)
ax_arr[1,1].plot([0, 1], [0, 1],'r--')
ax_arr[1,1].set_title('ROC Gaussian ',fontsize=20)
ax_arr[1,1].set_ylabel('True Positive Rate',fontsize=20)
ax_arr[1,1].set_xlabel('False Positive Rate',fontsize=15)
ax_arr[1,1].legend(loc = 'lower right', prop={'size': 16})

# Decision Tree
probs = dtree.predict_proba(X_test)
preds = probs[:,1]
fprdtree, tprdtree, thresholddtree = metrics.roc_curve(y_test, preds)
roc_aucdtree = metrics.auc(fprdtree, tprdtree)

ax_arr[1,0].plot(fprdtree, tprdtree, 'b', label = 'AUC = %0.2f' % roc_aucdtree)
ax_arr[1,0].plot([0, 1], [0, 1],'r--')
ax_arr[1,0].set_title('ROC Decision Tree ',fontsize=20)
ax_arr[1,0].set_ylabel('True Positive Rate',fontsize=20)
ax_arr[1,0].set_xlabel('False Positive Rate',fontsize=15)
ax_arr[1,0].legend(loc = 'lower right', prop={'size': 16})

#ALL PLOTS ----------------------------------
ax_arr[1,2].plot(fprgau, tprgau, 'b', label = 'Gaussian', color='black')
ax_arr[1,2].plot(fprdtree, tprdtree, 'b', label = 'Decision Tree', color='blue')
ax_arr[1,2].plot(fprknn, tprknn, 'b', label = 'Knn', color='brown')
ax_arr[1,2].plot(fprrfc, tprrfc, 'b', label = 'Random Forest', color='green')
ax_arr[1,2].plot(fprlog, tprlog, 'b', label = 'Logistic', color='grey')
ax_arr[1,2].set_title('Receiver Operating Comparison ',fontsize=20)
ax_arr[1,2].set_ylabel('True Positive Rate',fontsize=20)
ax_arr[1,2].set_xlabel('False Positive Rate',fontsize=15)
ax_arr[1,2].legend(loc = 'lower right', prop={'size': 16})

plt.subplots_adjust(wspace=0.2)
plt.tight_layout()

# %% [markdown]
# Na podstawie powyższych wybieramy model Random Forest.

# %% [markdown]
# ## Optymalizacja Random Forest

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
rf.fit(X_train, y_train)
ac = accuracy_score(y_test,rf.predict(X_test))
print('Accuracy dla Random Forest wynosi: ',ac, '\n')
# Out:
# Accuracy dla Random Forest wynosi:  0.9824098504837291

# %%
from collections import Counter
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
import numpy as np
import warnings

sm = SMOTE(random_state=1)
X_resampled, y_resampled = sm.fit_sample(X_train, y_train)

print('Original dataset shape:', Counter(y))
print('Resampled dataset shape:', Counter(y_resampled))

X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_resampled, y_resampled)
X_train_smote.shape, X_test_smote.shape, y_train_smote.shape, y_test_smote.shape, X_resampled.shape, y_resampled.shape

rf.fit(X_train_smote, y_train_smote)
# Out:
# Original dataset shape: Counter({0: 22315, 1: 422})
# Resampled dataset shape: Counter({0: 17846, 1: 17846})
# RandomForestClassifier(random_state=1)

# %%
preds1 = rf.predict(X_test_smote)
accs1 = np.mean(y_test_smote == preds1)
print(accs1)
# Out:
# 0.9794912025103665

# %%
importances = pd.DataFrame({'feature':X.columns,'importance':np.round(rf.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
print(importances)
# Out:
#                 feature  importance
# 13               INCOME        0.17
# 14                  AGE        0.16
# 4      NAME_INCOME_TYPE        0.11
# 12      CNT_FAM_MEMBERS        0.08
# 2       FLAG_OWN_REALTY        0.07
# 3          CNT_CHILDREN        0.07
# 1          FLAG_OWN_CAR        0.06
# 5   NAME_EDUCATION_TYPE        0.06
# 0           CODE_GENDER        0.06
# 10           FLAG_PHONE        0.05
# 9       FLAG_WORK_PHONE        0.04
# 6    NAME_FAMILY_STATUS        0.03
# 7     NAME_HOUSING_TYPE        0.03
# 11           FLAG_EMAIL        0.02
# 8            FLAG_MOBIL        0.00

# %%
feature_imp = pd.Series(random_forest.feature_importances_,index=iris.feature_names).sort_values(ascending=False)
feature_imp

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
random_forest = RandomForestClassifier(random_state = 1) 
params = {'n_estimators': [50, 100, 250, 500],
         'max_depth': [2, 3, 5, 10],
         'max_features': ['auto', 3, 5]}

# %%
grid = GridSearchCV(estimator=random_forest,
                   param_grid=params,
                   scoring='accuracy',
                   cv=10)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(random_state=1),
#              param_grid={'max_depth': [2, 3, 5, 10],
#                          'max_features': ['auto', 3, 5],
#                          'n_estimators': [50, 100, 250, 500]},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'max_depth': 2, 'max_features': 'auto', 'n_estimators': 50}

# %%
grid.best_score_
# Out:
# 0.9811424572913585

# %%
grid.best_estimator_.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=50, random_state=1)

# %%
preds = grid.best_estimator_.predict(X_test)

# %%
np.mean(y_test == preds)
# Out:
# 0.9826297273526825

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(y_test,preds)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print(optimal_threshold)

#Ze względu na niezbilansowanie zbioru (fraud jest zdarzeniem bardzo rzadkim) z powyżej analizy wychodzi, 
# że cut off jest równy 1, ale nie powinniśmy przyjąć takiej wartości.
# Out:
# 1

# %% [markdown]
# ## Wartość dodana dla banku

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

y_pred = grid.best_estimator_.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

cm_display = ConfusionMatrixDisplay(cm).plot()
